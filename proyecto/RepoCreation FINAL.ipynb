# %% [markdown]
# # Creation of the Document Repository (Wikipedia)

# %% [markdown]
# ## 1 Identification of the corpus from DBPedia
#
# ### 1.1 Get DBPedia concepts from the root concept

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDF, XML
#from bd import BDdatos
import codecs
import json
from datetime import date

# Variables to start the query process

e = "http://live.dbpedia.org/sparql"  # set the EndPoint: DBPedia Live

childConcepts = []

# %%
def getSubConcepts_byLevel(rootConcept, q, l):
    """
        Get sub-concepts of the root concept(s). Retrieve subconcepts located in three hops.
    """
    
    varP = ['c', 'level']
    sparql = SPARQLWrapper(e)
    
    query = """select distinct ?level ?r ?c1 ?c2 ?c3
    {
        {VALUES (?r ?level) {(<%s> 1)}
            # ?r ^skos:broader ?c1.}
        union
        {VALUES (?r ?level) {(<%s> 2)}
            # ?r ^skos:broader ?c1. ?c1 ^skos:broader ?c2.}
        union
        {VALUES (?r ?level) {(<%s> 3)}
            # ?r ^skos:broader ?c1. ?c1 ^skos:broader ?c2. ?c2 ^skos:broader ?c3.}
    }
    """
    numSC = 0 # number of subconcepts
    print("\t Processing...")
    for res in rootConcept:
        print("Root concept:", res)  
        sparql.setQuery(query%(res, res, res))
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            numSC += 1
            var1 = var2 = var3 = var4 = ''
            if varP[0] in result:
                var1 = result[varP[0]]["value"]
            if varP[1] in result:
                var2 = result[varP[1]]["value"]
            if varP[2] in result:
                var3 = result[varP[2]]["value"]
            if varP[3] in result:
                var4 = result[varP[3]]["value"]
            childConcepts.append([date.today().strftime("%d/%m/%Y"), res, var1, var2, var3, var4])
    
    print("Number of results:", numSC)

# %%
def getSubConcepts(rootConcept):
    """
        Get sub-concepts of the root concept(s). Retrieve subconcepts located in three hops.
    """
    
    varP = ['c1', 'c2', 'c3', 'level']
    sparql = SPARQLWrapper(e)
    
    query = """select distinct ?level ?r ?c1 ?c2 ?c3
    {
        {VALUES (?r ?level) {(<%s> 1)}
            # ?r ^skos:broader ?c1.}
        union
        {VALUES (?r ?level) {(<%s> 2)}
            # ?r ^skos:broader ?c1. ?c1 ^skos:broader ?c2.}
        union
        {VALUES (?r ?level) {(<%s> 3)}
            # ?r ^skos:broader ?c1. ?c1 ^skos:broader ?c2. ?c2 ^skos:broader ?c3.}
    }
    """
    numSC = 0 # number of subconcepts
    print("\t Processing...")
    for res in rootConcept:
        print("Root concept:", res)  
        sparql.setQuery(query%(res, res, res))
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            numSC += 1
            var1 = var2 = var3 = var4 = ''
            if varP[0] in result:
                var1 = result[varP[0]]["value"]
            if varP[1] in result:
                var2 = result[varP[1]]["value"]
            if varP[2] in result:
                var3 = result[varP[2]]["value"]
            if varP[3] in result:
                var4 = result[varP[3]]["value"]
            childConcepts.append([date.today().strftime("%d/%m/%Y"), res, var1, var2, var3, var4])
    
    print("Number of results:", numSC)

# %%
# To RUN:
getSubConcepts(["http://dbpedia.org/resource/Category:COVID-19"])  # Get subconcepts from the root concept
# Out:
# 	 Processing...
# Root concept: http://dbpedia.org/resource/Category:COVID-19
# Number of results: 170

# %%
childConcepts[44:50]

# lists, by_location
# Out:
# [['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:Medical_responses_to_the_COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:Hospitals_established_for_the_COVID-19_pandemic',
#   '',
#   '2'],
#  ['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture',
#   'http://dbpedia.org/resource/Category:Books_about_the_COVID-19_pandemic',
#   '3'],
#  ['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture',
#   'http://dbpedia.org/resource/Category:Works_about_the_COVID-19_pandemic',
#   '3'],
#  ['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture',
#   'http://dbpedia.org/resource/Category:Films_about_the_COVID-19_pandemic',
#   '3'],
#  ['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture',
#   'http://dbpedia.org/resource/Category:Songs_about_the_COVID-19_pandemic',
#   '3'],
#  ['16/05/2022',
#   'http://dbpedia.org/resource/Category:COVID-19',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic',
#   'http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture',
#   'http://dbpedia.org/resource/Category:Albums_about_the_COVID-19_pandemic',
#   '3']]

# %% [markdown]
# ### 1.2 Getting a unique list of concepts:

# %%
import pandas as pd

print("...Getting unique concepts")

blackList = ['organization', 'deaths', 'books', 'timelines', 'events', 'monuments', 'songs', 'film', 'album',  'television', 'films', 'company', 'list', 'http://dbpedia.org/ontology/']

#childConceptsDF = pd.DataFrame(childConcepts, columns = ['date', 'root', 'childLl1', 'childLl2', 'childLl3', 'level']) # ORIGINAL

childConceptsDF = pd.DataFrame(childConcepts[0:44], columns = ['date', 'root', 'childLl1', 'childLl2', 'childLl3', 'level'])

conceptList = list(childConceptsDF.childLl1.unique()) + list(childConceptsDF.childLl2.unique()) + list(childConceptsDF.childLl3.unique())
# Out:
# ...Getting unique concepts

# %%
def verify(c):
    for l in blackList:
        if l in c.lower():
            return False
    return True

conceptListSel = [c for c in conceptList if verify(c) and len(c)>0]
print(len(conceptListSel))

conceptListSel = pd.DataFrame(set(conceptListSel), columns=['concept'])
conceptListSel.tail()
# Out:
# 39
#                                               concept
# 32  http://dbpedia.org/resource/Category:Israeli_C...
# 33  http://dbpedia.org/resource/Category:Vietnames...
# 34  http://dbpedia.org/resource/Category:Statistic...
# 35  http://dbpedia.org/resource/Category:COVID-19_...
# 36  http://dbpedia.org/resource/Category:Medical_r...

# %%
# Depuración de conceptos
conceptListSel.to_csv('categories.csv', index = False)

# http://dbpedia.org/resource/Category:Songs_about_the_COVID-19_pandemic
#http://dbpedia.org/resource/Category:COVID-19_pandemic_in_the_United_States_in_popular_culture
#http://dbpedia.org/resource/Category:COVID-19_pandemic_in_popular_culture

# %%
# Depuración manual de categorías (conceptListSel):

conceptListSel = pd.read_csv('categories.csv')

# %%
conceptListSel
# Out:
#                                               concept
# 0       http://dbpedia.org/resource/Category:COVID-19
# 1   http://dbpedia.org/resource/Category:Works_abo...
# 2   http://dbpedia.org/resource/Category:Impact_of...
# 3   http://dbpedia.org/resource/Category:COVID-19_...
# 4   http://dbpedia.org/resource/Category:COVID-19_...
# 5   http://dbpedia.org/resource/Category:Deploymen...
# 6   http://dbpedia.org/resource/Category:COVID-19_...
# 7   http://dbpedia.org/resource/Category:COVID-19_...
# 8   http://dbpedia.org/resource/Category:COVID-19_...
# 9   http://dbpedia.org/resource/Category:COVID-19_...
# 10  http://dbpedia.org/resource/Category:Responses...
# 11  http://dbpedia.org/resource/Category:COVID-19_...
# 12  http://dbpedia.org/resource/Category:Vietnames...
# 13  http://dbpedia.org/resource/Category:Statistic...
# 14  http://dbpedia.org/resource/Category:COVID-19_...
# 15  http://dbpedia.org/resource/Category:Medical_r...
# 16  http://dbpedia.org/resource/Category:Impact_of...

# %% [markdown]
# ### 1.3. Getting Wikipage links and their metadata from DBPedia Live:
#
# <b>a. Creating the table:</b>

# %%
wikiPages = []

# %%
###########
# Get Pages:

import time, random

#S = requests.Session()

def getWikiPagesFromDBConcepts():
    #cur = con.cursor()
    print("Getting links from DBpedia:")
    # Insert data into new table:
    #cur.execute("""select distinct id, c from """ + stable + """ where id >""" +str(l1)+' and id <= ' + str(l2))
    #rowList = cur.fetchall()
    for row in conceptListSel.iterrows():
        idC = row[0]
        cat = row[1][0]
        print(idC, cat)
        results = getMetadata(cat)
        if results:
            for result in results:
                res = page = max_modif  = ''
                max_outDegree = 0
                res = result['r']["value"]
                if 'wikiPage' in result:
                    page = result['wikiPage']["value"]
                if 'classDBR' in result:
                    classDBR = result['classDBR']["value"]
                if 'wikiPageID' in result:
                    pageId = result['wikiPageID']["value"]                    
                if 'max_outDegree' in result:
                    max_outDegree = result['max_outDegree']["value"]
            
                wikiPages.append([date.today().strftime("%Y-%m-%d"), cat, res, classDBR, page, pageId, max_outDegree])
        time.sleep(2+random.uniform(0, 10))

def getMetadata(cat, user_agent='Mozilla/5.0', num_retries=3):
    sparql = SPARQLWrapper(e)
    try:
        # Pendiente el type de cada recurso:
        q = """SELECT DISTINCT ?r (GROUP_CONCAT(DISTINCT ?class; SEPARATOR=';') AS ?classDBR) ?wikiPage ?wikiPageID
        (str(max(?outDegree)) AS ?max_outDegree)
        WHERE{
        VALUES ?c {<%s>}
        # ?r dct:subject ?c .
        OPTIONAL {?r dbo:wikiPageModified ?modif.}
        OPTIONAL {?r dbo:wikiPageOutDegree ?outDegree.}
        OPTIONAL {?r foaf:isPrimaryTopicOf ?wikiPage.}
        OPTIONAL {?r rdf:type ?class.}
        OPTIONAL {?r dbo:wikiPageID ?wikiPageID}
        } GROUP BY ?r ?wikiPageID ?wikiPage"""
        sparql.setQuery(q%(cat))
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
    except socket.error as error:
        print('Error querying:', e.reason)
        #html = None
        if num_retries > 0:
            if hasattr(error, 'code') and 500 <= error.code < 600:
                return getMetadata(cat, user_agent, num_retries-1)
    return results["results"]["bindings"]

# %%
getWikiPagesFromDBConcepts() # Send range of ids to get pages: 281 (max id from tableDBIDs) len(conceptListSel)
# Out:
# Getting links from DBpedia:
# 0 http://dbpedia.org/resource/Category:COVID-19
# 1 http://dbpedia.org/resource/Category:Works_about_the_COVID-19_pandemic
# 2 http://dbpedia.org/resource/Category:Impact_of_the_COVID-19_pandemic
# 3 http://dbpedia.org/resource/Category:COVID-19_conspiracy_theorists
# 4 http://dbpedia.org/resource/Category:COVID-19_pandemic
# 5 http://dbpedia.org/resource/Category:Deployment_of_COVID-19_vaccines
# 6 http://dbpedia.org/resource/Category:COVID-19_models
# 7 http://dbpedia.org/resource/Category:COVID-19_drug_development
# 8 http://dbpedia.org/resource/Category:COVID-19_vaccines
# 9 http://dbpedia.org/resource/Category:COVID-19_misinformation
# 10 http://dbpedia.org/resource/Category:Responses_to_the_COVID-19_pandemic
# 11 http://dbpedia.org/resource/Category:COVID-19_symptoms
# 12 http://dbpedia.org/resource/Category:Vietnamese_COVID-19_vaccines
# 13 http://dbpedia.org/resource/Category:Statistics_of_the_COVID-19_pandemic
# 14 http://dbpedia.org/resource/Category:COVID-19_pandemic_by_location
# 15 http://dbpedia.org/resource/Category:Medical_responses_to_the_COVID-19_pandemic
# 16 http://dbpedia.org/resource/Category:Impact_of_the_COVID-19_pandemic

# %%
len(wikiPages) 

blackList = ['organization', 'deaths', 'books', 'timelines', 'events', 'monuments', 'song', 'album', 'awards',  'television', 'films', 'company', 'list', 'person']

wikiPagesDF = pd.DataFrame(wikiPages, columns = ['date', 'concept', 'dbr', 'class', 'wikipage', 'wikiPageID', 'max_outDegree'])

wikiPagesDF = wikiPagesDF[['class', 'wikipage', 'wikiPageID']].drop_duplicates()

#wikiPageID = wikiPagesDF.wikiPageID.unique()
wikiPagesDF.head()
# Out:
#                                                class  \
# 0                http://www.w3.org/2002/07/owl#Thing
# 1  http://dbpedia.org/class/yago/Abstraction10000...
# 2
# 3
# 4  http://dbpedia.org/ontology/Agent;http://dbped...
#
#                                             wikipage wikiPageID
# 0  http://en.wikipedia.org/wiki/COVID-19_drug_rep...   63430824
# 1           http://en.wikipedia.org/wiki/Favipiravir   40872327
# 2            http://en.wikipedia.org/wiki/Tika_Utsav   67366102
# 3      http://en.wikipedia.org/wiki/Solidarity_trial   63544717
# 4                http://en.wikipedia.org/wiki/Vaxart   63256201

# %%
wikiPageSel = pd.DataFrame(set([c[1][2] for c in wikiPagesDF.iterrows() if verify(c[1][0]+c[1][1])]), columns=['wikiPageID'])
print(len(wikiPageSel)) # 968
wikiPageSel[0:5]
# Out:
# 276
#   wikiPageID
# 0   63571861
# 1   67155086
# 2   67708405
# 3   65802682
# 4   64504133

# %%
pd.merge(wikiPageSel, wikiPagesDF[['wikiPageID', 'wikipage', 'class']]).to_csv('pages.csv')

wikiPageSel.wikiPageID.to_csv('wikiPages2022.csv')

# %% [markdown]
# ## Getting metadata of pages:

# %%
#from bd import BDdatos
import codecs
import json
from datetime import date
import re 
#from bs4 import BeautifulSoup
import urllib
#import wikipedia
import requests

URL = "https://en.wikipedia.org/w/api.php"

S = requests.Session()

import pandas as pd

wikiPages = pd.read_csv('wikiPages.csv')
wikiPages = list(wikiPages.wikiPageID); wikiPages[5]
# Out:
# 66188669

# %%
def getMetadata(pageid):
    pageid = str(pageid)
    PARAMS = {'action':'query',
        'pageids': pageid,
        'prop':'revisions|pageterms|info|pageviews',
        'rvprop':'ids|flags|timestamp|userid|user|size|comment|tags',
        'rvlimit':'500',
        'inprop':'url',
        "format": "json"
    }
    req = S.get(url=URL, params=PARAMS)
    data = req.json()
    #date = data["query"]['pages'][pageid]['revisions'][0]['timestamp'] 
    return data

# %%
metadataPages = []  # está guardado en wikiPagesMetadata.csv
pageviews = []   # No está bien guardado

# %%
#t = [66188669]

from itertools import cycle

for pageid in wikiPages:
    print(pageid)
    description = firstRev = lastRev = revid = title = url = None
    numRev = 0
    metadata = getMetadata(pageid)
    if 'title' in metadata["query"]['pages'][str(pageid)]:
        title = metadata["query"]['pages'][str(pageid)]['title']
    if 'revisions' in metadata["query"]['pages'][str(pageid)]:
        numRev = len(metadata["query"]['pages'][str(pageid)]['revisions'])
        lastRev = metadata["query"]['pages'][str(pageid)]['revisions'][0]['timestamp'][0:10]
        firstRev = metadata["query"]['pages'][str(pageid)]['revisions'][numRev-1]['timestamp'][0:10]
        revid = metadata["query"]['pages'][str(pageid)]['revisions'][0]['revid']
    if 'terms' in metadata["query"]['pages'][str(pageid)]:
        if 'description' in metadata["query"]['pages'][str(pageid)]['terms']:
            description = ';'.join(metadata["query"]['pages'][str(pageid)]['terms']['description'])
    if 'pageviews' in metadata["query"]['pages'][str(pageid)]:
        pageviews.append(list(zip(cycle([pageid]), metadata["query"]['pages'][str(pageid)]['pageviews'])))
    if 'fullurl' in metadata["query"]['pages'][str(pageid)]:
        url = metadata["query"]['pages'][str(pageid)]['fullurl']
    metadataPages.append([pageid, title, description, numRev, firstRev, lastRev, revid, url])
# Out:
# 66453368
# 65700804
# 63416817
# 63365057
# 67276075
# 66188669
# 63648639
# 67108361
# 63431821
# 63336518
# 63272141
# 63795020
# 63843248
# 68341990
# 63316213
# 68179014
# 65084949
# 67521729
# 63353421
# 63354227
# 63366021
# 63283461
# 63285738
# 62907551
# 68389568
# 63346121
# 63346138
# 65225706
# 63724991
# 67268564
# 65297373
# 63335287
# 67872083
# 65093951
# 63183247
# 59858954
# 67551548
# 63617842
# 65383730
# 63178636
# 63344613
# 63366078
# 63606106
# 68542482
# 63272917
# 64107722
# 65187376
# 56459486
# 67231916
# 53724240
# 63895130
# 64123343
# 66852270
# 67023308
# 63364910
# 63214876
# 66485227
# 66195384
# 66496391
# 62858715
# 65060446
# 63343158
# 68103267
# 63402681
# 61333254
# 68831719
# 64008008
# 64598873
# 66280945
# 63347679
# 66481246
# 63300653
# 63366066
# 67759831
# 63241849
# 65830027
# 63379589
# 67288169
# 63540207
# 66365133
# 66580737
# 63415229
# 63299502
# 67345750
# 67278940
# 64079576
# 67091267
# 68816648
# 68213064
# 63379158
# 63948936
# 62750956
# 63255772
# 63913842
# 63590050
# 65682288
# 64462283
# 63811805
# 61753359
# 66834168
# 63808158
# 48410011
# 66041794
# 68076170
# 63366079
# 67757201
# 67999171
# 65314337
# 878899
# 63627364
# 65527712
# 68257987
# 66772348
# 67294209
# 68035146
# 26139866
# 63609944
# 66120417
# 63366736
# 66553260
# 63136604
# 63378627
# 63341833
# 64705282
# 67851349
# 9297974
# 62526805
# 69054294
# 64744783
# 67286224
# 60528625
# 63322537
# 63272856
# 63344583
# 67967182
# 68246876
# 63341143
# 63482253
# 64555582
# 50629372
# 67036815
# 67983074
# 65370017
# 63337092
# 54326139
# 67967123
# 64651467
# 66656188
# 63277599
# 63954308
# 63445821
# 63255425
# 67967139
# 63979568
# 63397743
# 63337896
# 63338088
# 63828003
# 68004457
# 64086012
# 67769810
# 63570144
# 65684934
# 67466571
# 63607718
# 63299650
# 63544717
# 64454855
# 63808818
# 67971632
# 66866976
# 67576416
# 53304994
# 64096046
# 65643415
# 66002370
# 63350926
# 67277423
# 67286318
# 65164114
# 67487393
# 66677463
# 63754880
# 63397909
# 69100419
# 68717183
# 64400553
# 66403809
# 67324245
# 64538458
# 63161776
# 63346307
# 64133692
# 64695292
# 63242597
# 67967195
# 64138280
# 68396319
# 7138005
# 63262573
# 47372604
# 67539227
# 63923106
# 62858775
# 63754763
# 63420135
# 67206066
# 52322492
# 26647363
# 67194574
# 63362272
# 68557299
# 66208854
# 63519871
# 67802238
# 67982878
# 52732964
# 64554947
# 68810209
# 65255079
# 63366080
# 63366073
# 63370782
# 66342323
# 63890735
# 63247062
# 63254714
# 191513
# 63336450
# 63391022
# 63399660
# 63216845
# 63536836
# 65614028
# 67259438
# 63688874
# 65010666
# 67791451
# 67546334
# 67139751
# 63640929
# 4256674
# 63539132
# 66860910
# 63719042
# 65831507
# 63351627
# 63004998
# 67145871
# 65586468
# 64068317
# 63239190
# 63362023
# 63329148
# 64671338
# 63627329
# 63528961
# 67055598
# 62508887
# 67467304
# 66552852
# 48417209
# 63851129
# 63366719
# 63341139
# 63243638
# 67443988
# 67951357
# 63554423
# 63614409
# 68141295
# 64639486
# 63429959
# 67982893
# 63382568
# 64537261
# 63355677
# 66704000
# 61025478
# 63217081
# 63263950
# 68824909
# 68148257
# 64981054
# 63365020
# 63327604
# 67282435
# 63833158
# 63216548
# 66426813
# 62976235
# 62187536
# 67823318
# 67268476
# 67479301
# 67645512
# 63435566
# 64638311
# 67067814
# 63366720
# 64586749
# 64017094
# 66089296
# 66543207
# 63204759
# 63368404
# 67513717
# 64076419
# 63281706
# 63262527
# 66692273
# 66257254
# 63327327
# 67709278
# 63366077
# 63299322
# 67595013
# 67288474
# 63332056
# 53904227
# 68316611
# 63170193
# 63397934
# 63428771
# 67848628
# 63025456
# 64504133
# 64243070
# 63272131
# 63611718
# 64148447
# 63280866
# 67819031
# 63370492
# 63254676
# 63601740
# 63934082
# 63365851
# 63365028
# 63628033
# 67731326
# 63136490
# 63294337
# 68007736
# 62785398
# 2838286
# 63728510
# 66561327
# 63422087
# 63827000
# 63217011
# 68029784
# 63362222
# 67030365
# 68504378
# 63688345
# 63400209
# 63441669
# 66073502
# 65797150
# 63272036
# 63612268
# 67030150
# 63645596
# 66794278
# 68602473
# 66339084
# 62622700
# 63368430
# 67079102
# 274584
# 65243398
# 63926963
# 68526259
# 67189291
# 67400243
# 66732331
# 61161680
# 63683133
# 65969519
# 64327079
# 67294290
# 63293886
# 64415092
# 63261355
# 63488567
# 68613868
# 63893846
# 63142870
# 63532863
# 65338919
# 63887528
# 63639094
# 66054345
# 68690905
# 67630896
# 63351709
# 58667436
# 65655005
# 63369676
# 63366076
# 63365006
# 67006659
# 63451661
# 67188057
# 66328752
# 63313195
# 68602463
# 65837391
# 66938719
# 66389098
# 63858236
# 63216936
# 65430430
# 63272798
# 63359356
# 63366667
# 64109572
# 63641992
# 63025280
# 63364321
# 68247113
# 63364006
# 63884873
# 65254781
# 66586562
# 66426614
# 65300947
# 63366017
# 67036912
# 63366059
# 60663941
# 66402396
# 66673450
# 63464189
# 63274628
# 63649545
# 63696174
# 63560678
# 65418862
# 65934402
# 66504480
# 64182719
# 63289321
# 64295955
# 55607432
# 65746712
# 65908745
# 63390797
# 63276898
# 65365781
# 63599664
# 63378621
# 67276824
# 54528821
# 63906962
# 63811664
# 67225630
# 61764043
# 64777770
# 65277560
# 63366071
# 63627644
# 67828251
# 63683406
# 62705243
# 63364925
# 63444808
# 63435456
# 66958846
# 68039895
# 68476633
# 65059623
# 68068947
# 63260687
# 38097022
# 63609435
# 65930696
# 67349594
# 67894241
# 65830161
# 65418863
# 63327841
# 69128665
# 64760870
# 31757223
# 65562123
# 66508327
# 64635178
# 63055098
# 67453426
# 63300608
# 18890985
# 67281144
# 63366054
# 65762043
# 68525295
# 63358779
# 64598482
# 67278807
# 67013709
# 65043140
# 63630677
# 66948202
# 66326404
# 67631900
# 63945131
# 67994634
# 66978482
# 65660124
# 63113361
# 63216759
# 68620427
# 63364122
# 65995815
# 67009566
# 63222928
# 65724585
# 63482263
# 68587138
# 63765505
# 66232670
# 63354085
# 61933429
# 63275617
# 64611308
# 63277046
# 63366081
# 66243733
# 67485313
# 63520128
# 63354091
# 61610792
# 66976335
# 67270412
# 67381531
# 68832274
# 63621509
# 63346188
# 63708366
# 13707910
# 67025627
# 64038918
# 63881567
# 64598656
# 63566901
# 63277990
# 67791457
# 63272144
# 56624269
# 32093273
# 63354087
# 64630786
# 65296793
# 64530138
# 63273278
# 66301348
# 332416
# 63734774
# 39419916
# 64451057
# 63365068
# 63608864
# 65720446
# 68391132
# 67195671
# 67060856
# 65802682
# 66601883
# 63585221
# 63005351
# 63776799
# 63769277
# 67044747
# 67269840
# 62918424
# 66913581
# 63842033
# 63462234
# 63366724
# 67543997
# 63879284
# 67493507
# 68221196
# 88988
# 66391815
# 63526358
# 1992390
# 63384317
# 68555668
# 66306149
# 63289309
# 64392045
# 60870605
# 63366743
# 63645137
# 65332238
# 65508154
# 1988214
# 64421134
# 63362360
# 67632179
# 63567756
# 68750333
# 65141256
# 64171051
# 63364407
# 64634061
# 67055625
# 66899395
# 63453597
# 66043446
# 67036875
# 63407428
# 67286405
# 64792624
# 68833019
# 67101199
# 66485074
# 66557065
# 64790560
# 67967188
# 64107435
# 63676221
# 64380196
# 66590710
# 67967179
# 63509217
# 63366086
# 63316879
# 68896635
# 63446562
# 66159982
# 66911486
# 63606142
# 63341569
# 63364964
# 61017442
# 66208983
# 68442310
# 68340429
# 68597435
# 67019071
# 63364916
# 67920418
# 67248101
# 49100118
# 64332973
# 63816035
# 63571861
# 63355934
# 65088776
# 63611878
# 64409779
# 66613185
# 61861326
# 63281785
# 67427795
# 63195508
# 64557026
# 66056960
# 64046884
# 66125058
# 64145180
# 63215769
# 63244299
# 64399515
# 63408028
# 63336523
# 67499398
# 68425756
# 65212280
# 63560672
# 65414439
# 63365017
# 66959767
# 63423368
# 63775420
# 63362621
# 64327424
# 45266358
# 63178675
# 67594746
# 63489614
# 63473161
# 63299729
# 63370773
# 63963606
# 63706543
# 63354065
# 65064451
# 63795044
# 63900790
# 47329893
# 64624242
# 63368514
# 62938755
# 63550143
# 66392176
# 65328211
# 67442846
# 64740866
# 66018844
# 63519761
# 67283844
# 59793033
# 65210323
# 63196010
# 67788175
# 68532309
# 65875084
# 67059208
# 67388098
# 65453990
# 59783118
# 67286060
# 63352464
# 62952907
# 63560284
# 62128016
# 63281920
# 63435931
# 63384292
# 63249910
# 63182945
# 63327574
# 63366084
# 66176295
# 62976420
# 68883987
# 65553379
# 243387
# 65198986
# 67155086
# 40424647
# 63497905
# 63354230
# 63243000
# 63300750
# 65891895
# 63265538
# 68017962
# 67982885
# 57651994
# 18606020
# 63870105
# 64950617
# 64658610
# 64680327
# 63364860
# 63678830
# 63228857
# 63589782
# 65560459
# 63787967
# 64719181
# 63364099
# 63136305
# 67521166
# 63694441
# 67624827
# 63319438
# 64481081
# 63272041
# 67269270
# 37369338
# 52320669
# 64302080
# 66995030
# 66091458
# 66744144
# 63181042
# 67029513
# 66463200
# 63365082
# 63966151
# 68750860
# 68842953
# 63281894
# 66504992
# 66115428
# 63136199
# 64945601
# 63436865
# 63556332
# 61618326
# 47373930
# 63393876
# 67877826
# 68109336
# 65735076
# 67115929
# 63047099
# 63258096
# 65526255
# 67540209
# 63790837
# 63365072
# 66082489
# 63796991
# 64664953
# 63362010
# 63560792
# 67164310
# 63366069
# 67242622
# 65863464
# 63555287
# 67967191
# 67043144
# 64549287
# 63560826
# 63281815
# 64495562
# 63499429
# 63178596
# 63366020
# 64294164
# 63366070
# 63372248
# 63366018
# 63364944
# 67151002
# 67036568
# 64800626
# 66221163
# 63370785
# 63439802
# 65477948
# 63808501
# 67500634
# 63665310
# 63613677
# 69109465
# 63281933
# 66071128
# 66503974
# 67967128
# 63244125
# 63315611
# 66699320
# 67631343
# 67189403
# 66371595
# 52506938
# 64626988
# 63304474
# 64023322
# 64198548
# 63300912
# 63824523
# 62103610
# 63804580
# 67184914
# 63630438
# 60634575
# 67666854
# 63637163
# 63500512
# 64049906
# 63260725
# 68331624
# 66791498
# 67361886
# 63548286
# 63594947
# 63422845
# 69045728
# 63562819
# 68771298
# 66637128
# 63969760
# 63531353
# 65082081
# 63262215
# 63273458
# 63348169
# 67466645
# 66168599
# 68534951
# 63939389
# 63329395
# 63366586
# 66048484
# 2460052
# 65944486
# 67371669
# 68331598
# 67932079
# 63573768
# 54450713
# 65130522
# 68677280
# 63631542
# 63127009
# 64540171
# 68153320
# 65511723
# 63635398
# 63695683
# 68714331
# 63039926
# 63751472
# 66141405
# 63480383
# 63344447
# 66139472
# 65845227
# 66346452
# 63642091
# 64744778
# 37017979
# 66431202
# 63821674
# 63397600
# 67123375
# 63364001
# 69053934
# 65007833
# 65911967
# 2532674
# 63478388
# 63636316
# 63262762
# 64118463
# 62508050
# 63647244
# 64244400
# 67189736
# 64192678
# 63430824
# 63366056
# 67276945
# 63948123
# 64958366
# 63313047
# 66409096
# 64624687
# 63262736
# 66456258
# 64349520
# 64360653
# 63843654
# 63750595
# 41884787
# 63842737
# 64003195
# 62257865
# 63362225
# 63381322
# 68199446
# 67911325
# 65467447
# 63366035
# 65480227
# 63113319
# 68841583
# 63560856
# 67818951
# 63636485
# 63801738
# 63631325
# 63808182
# 63866435
# 64063338
# 63264158
# 63634124
# 66546768

# %%
metadataPagesDF = pd.DataFrame(metadataPages, columns=['wikipageID', 'title', 'description', 'numRev', 'firstRev', 'lastRev', 'revid', 'url'])
metadataPagesDF.head(5) #[metadataPagesDF['url'] == None]

# To save metadata
metadataPagesDF.to_csv('wikiPagesMetadata2.csv')

# %% [markdown]
# <b> c. Validating Wikipage links (there are some redirects)</b>

# %% [markdown]
# ## 2. Getting  data from Wikipedia
#
# ### 2.1 Extracting metadata of pages
#
# <b> a. Creating tables </b>

# %%
wikiPageError = [] # etable 
wikiPageCategories = [] # ctable
wikiPageWikiProjects  = [] # ptable
wikiPageTOC  = [] # toctable

# %% [markdown]
# <b> b. Extracting metadata of Wikipages </b>

# %%
#from bd import BDdatos
import codecs
import json
from datetime import date
import re 
#from bs4 import BeautifulSoup
import urllib
#import wikipedia
import requests

URL = "https://en.wikipedia.org/w/api.php"

S = requests.Session()

#db = BDdatos()
#con = db.conectar()

################
# Get TOC:
def getPageID(l1, l2):
    #cur = con.cursor()
    print("Downloading information from Wikipedia:")
    #cur = con.cursor()
    #cur.execute("""SELECT distinct id, wikipageUrl FROM """ + otable + """ WHERE id >""" +str(l1)+' and id <= ' + str(l2))
    #rowList = cur.fetchall()
    wikipageList = metadataPagesDF[['wikipageID', 'url']]
    for row in range(l1, l2):
        idP = wikipageList.iloc[row][0]
        page =  wikipageList.iloc[row][1]
        print(idP, page)
        getMoreMetadata(idP, page)


def getMoreMetadata(idP, page):
    S = requests.Session() 
     
    #urllib.parse.unquote(page),
    PARAMS = {
        "action": "parse",
        "pageid": str(idP), 
        "format": "json"
    }

    R = S.get(url=URL, params=PARAMS)
    DATAC = R.json()
    if 'error' in DATAC:
        error = DATAC['error']['info']
        print(error)
        wikiPageError.append([date.today().strftime("%Y-%m-%d"), idP])
    else:    
        DATAC = DATAC['parse']

        #Wikipedia Categories:
        for l in DATAC['categories']:
            if 'hidden' not in l:
                wikiPageCategories.append([date.today().strftime("%Y-%m-%d"), idP, l['*']])

        #iwlinks, wikipedia projects:
        for l in DATAC['iwlinks']:
            wikiPageWikiProjects.append([date.today().strftime("%Y-%m-%d"), idP, l['prefix'], l['url'], l['*']])
    
        # TOC:
        toc = DATAC['sections']
        for i in toc:
            fromtitle = ''
            if 'fromtitle' in i:
                fromtitle = i['fromtitle']
            wikiPageTOC.append([date.today().strftime("%Y-%m-%d"), idP, i['toclevel'], i['level'], i['line'], i['number'], i['index'], fromtitle, i['anchor']])

# %%
# To run:
metadataPagesDF.tail()
getPageID(0, 968) # 2637 validated pages
# Out:
# Downloading information from Wikipedia:
# 66453368 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_April_2021
# 65700804 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Malaysia
# 63416817 https://en.wikipedia.org/wiki/Media_coverage_of_the_COVID-19_pandemic
# 63365057 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Marshall_Islands
# 67276075 https://en.wikipedia.org/wiki/Sinopharm_WIBP_COVID-19_vaccine
# 66188669 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Switzerland
# 63648639 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Brazil
# 67108361 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic
# 63431821 https://en.wikipedia.org/wiki/Coronavirus_Tech_Handbook
# 63336518 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Oman
# 63272141 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Israel
# 63795020 https://en.wikipedia.org/wiki/Trikini
# 63843248 https://en.wikipedia.org/wiki/COVID-19_anti-lockdown_protests_in_the_United_States
# 68341990 https://en.wikipedia.org/wiki/GBP510
# 63316213 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Malta
# 68179014 https://en.wikipedia.org/wiki/Peter_A._McCullough
# 65084949 https://en.wikipedia.org/wiki/CoronaVac
# 67521729 https://en.wikipedia.org/wiki/PF-07321332
# 63353421 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guyana
# 63354227 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Jordan
# 63366021 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Burundi
# 63283461 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Hungary
# 63285738 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Egypt
# 62907551 https://en.wikipedia.org/wiki/COVID-19_lockdown_in_China
# 68389568 https://en.wikipedia.org/wiki/Love_is_not_tourism
# 63346121 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Peru
# 63346138 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Maldives
# 65225706 https://en.wikipedia.org/wiki/OK_Not_to_Be_OK
# 63724991 https://en.wikipedia.org/wiki/Decentralized_Privacy-Preserving_Proximity_Tracing
# 67268564 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Vietnam
# 65297373 https://en.wikipedia.org/wiki/Vaccine_Taskforce
# 63335287 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Nigeria
# 67872083 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Taiwan
# 65093951 https://en.wikipedia.org/wiki/Coronavirus_Alleviation_Program
# 63183247 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Asia
# 59858954 https://en.wikipedia.org/wiki/Jelle%27s_Marble_Runs
# 67551548 https://en.wikipedia.org/wiki/2021_Colombian_protests
# 63617842 https://en.wikipedia.org/wiki/Pan-European_Privacy-Preserving_Proximity_Tracing
# 65383730 https://en.wikipedia.org/wiki/PolyAnalyst
# 63178636 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Taiwan
# 63344613 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Jersey
# 63366078 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Sudan
# 63606106 https://en.wikipedia.org/wiki/National_Public_Health_Emergency_Team_(2020)
# 68542482 None
# There is no page with ID 68542482.
# 63272917 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sri_Lanka
# 64107722 https://en.wikipedia.org/wiki/We_Are_One:_A_Global_Film_Festival
# 65187376 https://en.wikipedia.org/wiki/GeForce_30_series
# 56459486 https://en.wikipedia.org/wiki/2020_Democratic_National_Convention
# 67231916 https://en.wikipedia.org/wiki/Sanofi%E2%80%93GSK_COVID-19_vaccine
# 53724240 https://en.wikipedia.org/wiki/Retail_apocalypse
# 63895130 https://en.wikipedia.org/wiki/Multisystem_inflammatory_syndrome_in_children
# 64123343 https://en.wikipedia.org/wiki/Federal_aid_during_the_COVID-19_pandemic_in_Canada
# 66852270 https://en.wikipedia.org/wiki/Hygiene_theater
# 67023308 https://en.wikipedia.org/wiki/2021_Paraguayan_protests
# 63364910 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mali
# 63214876 https://en.wikipedia.org/wiki/2020%E2%80%9321_Malaysian_political_crisis
# 66485227 https://en.wikipedia.org/wiki/Triple_Stimulus_Voucher
# 66195384 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Singapore
# 66496391 https://en.wikipedia.org/wiki/2016%E2%80%932021_Iranian_protests
# 62858715 https://en.wikipedia.org/wiki/2020_LCS_season
# 65060446 https://en.wikipedia.org/wiki/Artificial_crowd_noise
# 63343158 https://en.wikipedia.org/wiki/E3_2021
# 68103267 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Turkey
# 63402681 https://en.wikipedia.org/wiki/Safe_Hands_Challenge
# 61333254 https://en.wikipedia.org/wiki/Olympic_Games_Tokyo_2020_-_The_Official_Video_Game
# 68831719 https://en.wikipedia.org/wiki/German_government_response_to_the_COVID-19_pandemic
# 64008008 https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_Play-Offs
# 64598873 https://en.wikipedia.org/wiki/Nobody%27s_Love
# 66280945 https://en.wikipedia.org/wiki/2020_United_States_presidential_election_predictions
# 63347679 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Paraguay
# 66481246 https://en.wikipedia.org/wiki/2021_French_labor_protests
# 63300653 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Africa
# 63366066 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Liberia
# 67759831 https://en.wikipedia.org/wiki/Mask_refusal
# 63241849 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Switzerland
# 65830027 https://en.wikipedia.org/wiki/AbC-19_rapid_antibody_test
# 63379589 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_education
# 67288169 https://en.wikipedia.org/wiki/DelNS1-2019-nCoV-RBD-OPT
# 63540207 https://en.wikipedia.org/wiki/NHS_Louisa_Jordan
# 66365133 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Israel
# 66580737 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Romania
# 63415229 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Akrotiri_and_Dhekelia
# 63299502 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Serbia
# 67345750 https://en.wikipedia.org/wiki/Use_and_development_of_software_for_COVID-19_pandemic_mitigation
# 67278940 https://en.wikipedia.org/wiki/AG0302-COVID%E2%80%9119
# 64079576 https://en.wikipedia.org/wiki/2020_Mid-Season_Streamathon
# 67091267 https://en.wikipedia.org/wiki/CoviVac_(Russia_COVID-19_vaccine)
# 68816648 https://en.wikipedia.org/wiki/Global_Citizen_Live
# 68213064 https://en.wikipedia.org/wiki/2021_Cuban_protests
# 63379158 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_arts_and_cultural_heritage
# 63948936 https://en.wikipedia.org/wiki/UFC_Fight_Night:_Smith_vs._Teixeira
# 62750956 https://en.wikipedia.org/wiki/COVID-19_pandemic
# 63255772 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Croatia
# 63913842 https://en.wikipedia.org/wiki/COVID_Symptom_Study
# 63590050 https://en.wikipedia.org/wiki/European_Union_response_to_the_COVID-19_pandemic
# 65682288 https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_3
# 64462283 https://en.wikipedia.org/wiki/Pradhan_Mantri_Garib_Kalyan_Anna_Yojana
# 63811805 https://en.wikipedia.org/wiki/The_Disney_Family_Singalong:_Volume_II
# 61753359 https://en.wikipedia.org/wiki/101_Dalmatians_(2022_musical)
# 66834168 https://en.wikipedia.org/wiki/Spaceman_(Nick_Jonas_song)
# 63808158 https://en.wikipedia.org/wiki/Mas(k)ot
# 48410011 https://en.wikipedia.org/wiki/2020_United_States_presidential_election
# 66041794 https://en.wikipedia.org/wiki/Bio-secure_bubble
# 68076170 https://en.wikipedia.org/wiki/Proximity_chat
# 63366079 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Tanzania
# 67757201 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Japan
# 67999171 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Haiti
# 65314337 https://en.wikipedia.org/wiki/Casirivimab/imdevimab
# 878899 https://en.wikipedia.org/wiki/USNS_Comfort_(T-AH-20)
# 63627364 https://en.wikipedia.org/wiki/Canberra_Coronavirus_Field_Hospital
# 65527712 https://en.wikipedia.org/wiki/Ben_Ramalingam
# 68257987 https://en.wikipedia.org/wiki/Scientific_Advisory_Group_for_Origins_of_Novel_Pathogens
# 66772348 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Canada
# 67294209 https://en.wikipedia.org/wiki/TurkoVac
# 68035146 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Thailand
# 26139866 https://en.wikipedia.org/wiki/Christmas_Island_Detention_Centre
# 63609944 https://en.wikipedia.org/wiki/Dragon%27s_Heart_Hospital
# 66120417 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_United_Kingdom
# 63366736 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Myanmar
# 66553260 https://en.wikipedia.org/wiki/COVIran_Barekat
# 63136604 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Vietnam
# 63378627 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Nicaragua
# 63341833 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bolivia
# 64705282 https://en.wikipedia.org/wiki/2020_Supercopa_de_Espa%C3%B1a_de_Baloncesto
# 67851349 https://en.wikipedia.org/wiki/2021_PGCBL_season
# 9297974 https://en.wikipedia.org/wiki/KRI_dr._Soeharso
# 62526805 https://en.wikipedia.org/wiki/2020_Overwatch_League_season
# 69054294 https://en.wikipedia.org/wiki/Independent_Panel_for_Pandemic_Preparedness_and_Response
# 64744783 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_January_2021
# 67286224 https://en.wikipedia.org/wiki/West_China_Hospital_COVID-19_vaccine
# 60528625 https://en.wikipedia.org/wiki/Red_Sea_International_Film_Festival
# 63322537 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Albania
# 63272856 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Czech_Republic
# 63344583 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Panama
# 67967182 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Egypt
# 68246876 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Portugal
# 63341143 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Turkey
# 63482253 https://en.wikipedia.org/wiki/Outbreak_response
# 64555582 https://en.wikipedia.org/wiki/2020%E2%80%932021_Bulgarian_protests
# 50629372 https://en.wikipedia.org/wiki/Super_Bowl_LV
# 67036815 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Botswana
# 67983074 https://en.wikipedia.org/wiki/Waiver_from_certain_provisions_of_the_TRIPS_Agreement_for_the_Prevention,_Containment_and_Treatment_of_COVID-19
# 65370017 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Sahrawi_Arab_Democratic_Republic
# 63337092 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cambodia
# 54326139 https://en.wikipedia.org/wiki/Atari_VCS_(2021_console)
# 67967123 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Burundi
# 64651467 https://en.wikipedia.org/wiki/Inauguration_of_Joe_Biden
# 66656188 https://en.wikipedia.org/wiki/COVID-19_and_homelessness
# 63277599 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_New_Zealand
# 63954308 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Chandigarh
# 63445821 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_%C3%85land_Islands
# 63255425 https://en.wikipedia.org/wiki/Industry_Bar
# 67967139 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Chad
# 63979568 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_other_health_issues
# 63397743 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Vanuatu
# 63337896 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Afghanistan
# 63338088 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_aviation
# 63828003 https://en.wikipedia.org/wiki/Hum_Haar_Nahi_Maanenge
# 68004457 https://en.wikipedia.org/wiki/Merafloxacin
# 64086012 https://en.wikipedia.org/wiki/Club_Cumming
# 67769810 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Brazil
# 63570144 https://en.wikipedia.org/wiki/Social_stigma_associated_with_COVID-19
# 65684934 https://en.wikipedia.org/wiki/Pac-Man_40th_Anniversary
# 67466571 https://en.wikipedia.org/wiki/V-01
# 63607718 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_Diamond_Princess
# 63299650 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Vatican_City
# 63544717 https://en.wikipedia.org/wiki/Solidarity_trial
# 64454855 https://en.wikipedia.org/wiki/Parasite_Eve_(song)
# 63808818 https://en.wikipedia.org/wiki/Mega_Ligtas_COVID_Centers
# 67971632 https://en.wikipedia.org/wiki/CV2CoV
# 66866976 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Peru
# 67576416 https://en.wikipedia.org/wiki/Community_pantries_in_the_Philippines
# 53304994 https://en.wikipedia.org/wiki/Danoprevir
# 64096046 https://en.wikipedia.org/wiki/We_Are_One_(global_collaboration_song)
# 65643415 https://en.wikipedia.org/wiki/Can%27t_Wait_to_Be_Dead
# 66002370 https://en.wikipedia.org/wiki/Vaccination_requirements_for_international_travel
# 63350926 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_America
# 67277423 https://en.wikipedia.org/wiki/Sanofi%E2%80%93Translate_Bio_COVID-19_vaccine
# 67286318 https://en.wikipedia.org/wiki/Walvax_COVID-19_vaccine
# 65164114 https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_2
# 67487393 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Indonesia
# 66677463 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Albania
# 63754880 https://en.wikipedia.org/wiki/2020_W-League_Grand_Final
# 63397909 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Dominica
# 69100419 https://en.wikipedia.org/wiki/CureVac%E2%80%93GSK_COVID-19_vaccine
# 68717183 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Pakistan
# 64400553 https://en.wikipedia.org/wiki/Be_Happy_(Dixie_D%27Amelio_song)
# 66403809 https://en.wikipedia.org/wiki/American_Rescue_Plan_Act_of_2021
# 67324245 https://en.wikipedia.org/wiki/NDV-HXP-S
# 64538458 https://en.wikipedia.org/wiki/77th_Venice_International_Film_Festival
# 63161776 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Korea
# 63346307 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bangladesh
# 64133692 https://en.wikipedia.org/wiki/Viral_disease_testing
# 64695292 https://en.wikipedia.org/wiki/Thank_You_NHS
# 63242597 https://en.wikipedia.org/wiki/2020_PCS_season
# 67967195 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Eswatini
# 64138280 https://en.wikipedia.org/wiki/Ye%C5%9Filk%C3%B6y_Prof._Dr._Murat_Dilmener_Emergency_Hospital
# 68396319 https://en.wikipedia.org/wiki/2021_Minas_Gerais_prostitute_strike
# 7138005 https://en.wikipedia.org/wiki/The_Jewish_Advocate
# 63262573 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Belgium
# 47372604 https://en.wikipedia.org/wiki/Canton_of_Belleville-en-Beaujolais
# 67539227 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Bangladesh
# 63923106 https://en.wikipedia.org/wiki/Arivum_Anbum
# 62858775 https://en.wikipedia.org/wiki/2020_LEC_season
# 63754763 https://en.wikipedia.org/wiki/COVID-19_Immunity_Task_Force
# 63420135 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Delhi
# 67206066 https://en.wikipedia.org/wiki/Development_of_COVID-19_tests
# 52322492 https://en.wikipedia.org/wiki/Remdesivir
# 26647363 https://en.wikipedia.org/wiki/Travel_ban
# 67194574 https://en.wikipedia.org/wiki/2021_Columbia_University_strike
# 63362272 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Kazakhstan
# 68557299 https://en.wikipedia.org/wiki/COVID-19_protests_in_Australia
# 66208854 https://en.wikipedia.org/wiki/Lesbian_Bar_Project
# 63519871 https://en.wikipedia.org/wiki/COVID_Tracking_Project
# 67802238 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Iceland
# 67982878 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_Central_African_Republic
# 52732964 https://en.wikipedia.org/wiki/Mean_Girls_(musical)
# 64554947 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_retail
# 68810209 https://en.wikipedia.org/wiki/SCB-2020S
# 65255079 https://en.wikipedia.org/wiki/Super_Mario_Bros._35th_Anniversary
# 63366080 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Uganda
# 63366073 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Rwanda
# 63370782 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Bahamas
# 66342323 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Italy
# 63890735 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_fashion_industry
# 63247062 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Ecuador
# 63254714 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Norway
# 191513 https://en.wikipedia.org/wiki/USNS_Mercy_(T-AH-19)
# 63336450 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Costa_Rica
# 63391022 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_the_Congo
# 63399660 https://en.wikipedia.org/wiki/Moderna_COVID-19_vaccine
# 63216845 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Germany
# 63536836 https://en.wikipedia.org/wiki/COVID-19_apps
# 65614028 https://en.wikipedia.org/wiki/So_Will_I_(Ben_Platt_song)
# 67259438 https://en.wikipedia.org/wiki/Stop_Asian_Hate
# 63688874 https://en.wikipedia.org/wiki/Pyongyang_General_Hospital
# 65010666 https://en.wikipedia.org/wiki/Emergency_evacuation_procedures_during_the_COVID-19_pandemic
# 67791451 https://en.wikipedia.org/wiki/TAK-019
# 67546334 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_May_2021
# 67139751 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Ghana
# 63640929 https://en.wikipedia.org/wiki/Social_distancing_measures_related_to_the_COVID-19_pandemic
# 4256674 https://en.wikipedia.org/wiki/Ninoy_Aquino_Stadium
# 63539132 https://en.wikipedia.org/wiki/Be_a_Light
# 66860910 https://en.wikipedia.org/wiki/COVID-19_anti-lockdown_protests_in_Canada
# 63719042 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic
# 65831507 https://en.wikipedia.org/wiki/Kirby_Fighters_2
# 63351627 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Jamaica
# 63004998 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_mainland_China
# 67145871 https://en.wikipedia.org/wiki/PTX-COVID19-B
# 65586468 https://en.wikipedia.org/wiki/COVID_toe
# 64068317 https://en.wikipedia.org/wiki/Youyang_Gu_COVID_model
# 63239190 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sweden
# 63362023 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Ghana
# 63329148 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_cinema
# 64671338 https://en.wikipedia.org/wiki/International_Film_Festival_of_Ottawa
# 63627329 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_Charles_de_Gaulle
# 63528961 https://en.wikipedia.org/wiki/COVID-19_hospitals_in_the_United_Kingdom
# 67055598 https://en.wikipedia.org/wiki/Inovio_COVID-19_vaccine
# 62508887 https://en.wikipedia.org/wiki/UFC_Fight_Night:_Lee_vs._Oliveira
# 67467304 https://en.wikipedia.org/wiki/GX-19
# 66552852 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_France
# 48417209 https://en.wikipedia.org/wiki/2020_United_States_elections
# 63851129 https://en.wikipedia.org/wiki/Contingencies_Fund_Act_2020
# 63366719 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Turkmenistan
# 63341139 https://en.wikipedia.org/wiki/National_responses_to_the_COVID-19_pandemic
# 63243638 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Poland
# 67443988 https://en.wikipedia.org/wiki/Impact_of_COVID-19_on_suicide_rates
# 67951357 https://en.wikipedia.org/wiki/FAKHRAVAC
# 63554423 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_USS_Theodore_Roosevelt
# 63614409 https://en.wikipedia.org/wiki/Pandemic_predictions_and_preparations_prior_to_the_COVID-19_pandemic
# 68141295 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Denmark
# 64639486 https://en.wikipedia.org/wiki/Swedish_government_response_to_the_COVID-19_pandemic
# 63429959 https://en.wikipedia.org/wiki/I_Miss_One_Week_Ago
# 67982893 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_Democratic_Republic_of_the_Congo
# 63382568 https://en.wikipedia.org/wiki/White_House_Coronavirus_Task_Force
# 64537261 https://en.wikipedia.org/wiki/Graduation2020
# 63355677 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_sports
# 66704000 https://en.wikipedia.org/wiki/2021_Mongolian_protests
# 61025478 https://en.wikipedia.org/wiki/TurboGrafx-16_Mini
# 63217081 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Australia
# 63263950 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Russia
# 68824909 https://en.wikipedia.org/wiki/2021_Oregon_Tech_strike
# 68148257 https://en.wikipedia.org/wiki/Fall_2021_National_Independent_Soccer_Association_season
# 64981054 https://en.wikipedia.org/wiki/2020_UK_GCSE_and_A-Level_grading_controversy
# 63365020 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Madagascar
# 63327604 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Azerbaijan
# 67282435 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Mexico
# 63833158 https://en.wikipedia.org/wiki/Six_Feet_Apart
# 63216548 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Canada
# 66426813 https://en.wikipedia.org/wiki/History_of_COVID-19_vaccine_development
# 62976235 https://en.wikipedia.org/wiki/Dabie_Mountain_Regional_Medical_Centre
# 62187536 https://en.wikipedia.org/wiki/2020_Stadium_Super_Trucks_season
# 67823318 https://en.wikipedia.org/wiki/Economic_Recovery_Plan_2021
# 67268476 https://en.wikipedia.org/wiki/Nanocovax
# 67479301 https://en.wikipedia.org/wiki/Contingencies_Fund_Act_2021
# 67645512 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Singapore
# 63435566 https://en.wikipedia.org/wiki/Digital_Drag_Fest
# 64638311 https://en.wikipedia.org/wiki/Virtual_choir
# 67067814 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_New_Zealand
# 63366720 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Uzbekistan
# 64586749 https://en.wikipedia.org/wiki/Oxford%E2%80%93AstraZeneca_COVID-19_vaccine
# 64017094 https://en.wikipedia.org/wiki/Seattle_Coronavirus_Assessment_Network
# 66089296 https://en.wikipedia.org/wiki/Sinopharm_BIBP_COVID-19_vaccine
# 66543207 https://en.wikipedia.org/wiki/2021_Brazilian_protests
# 63204759 https://en.wikipedia.org/wiki/COVID-19_testing
# 63368404 https://en.wikipedia.org/wiki/The_Uncensored_Library
# 67513717 https://en.wikipedia.org/wiki/Michael_Yeadon
# 64076419 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Tamil_Nadu
# 63281706 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Latvia
# 63262527 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Denmark
# 66692273 https://en.wikipedia.org/wiki/COVID-19_lab_leak_theory
# 66257254 https://en.wikipedia.org/wiki/COVID-19_scams
# 63327327 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cyprus
# 67709278 https://en.wikipedia.org/wiki/Headroom_LGBTQ%2B_Lounge
# 63366077 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sierra_Leone
# 63299322 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_State_of_Palestine
# 67595013 https://en.wikipedia.org/wiki/Emergency_Broadband_Benefit
# 67288474 https://en.wikipedia.org/wiki/Vabiotech_COVID-19_vaccine
# 63332056 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mongolia
# 53904227 https://en.wikipedia.org/wiki/SevenHills_Hospital
# 68316611 https://en.wikipedia.org/wiki/2021_State_of_the_Nation_Address_(Philippines)
# 63170193 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Japan
# 63397934 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Grenada
# 63428771 https://en.wikipedia.org/wiki/New_and_Emerging_Respiratory_Virus_Threats_Advisory_Group
# 67848628 https://en.wikipedia.org/wiki/COVID-19_vaccine_card
# 63025456 https://en.wikipedia.org/wiki/Social_impact_of_the_COVID-19_pandemic
# 64504133 https://en.wikipedia.org/wiki/Serbian_protests_(2020%E2%80%93)
# 64243070 https://en.wikipedia.org/wiki/High_Low_(song)
# 63272131 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Iraq
# 63611718 https://en.wikipedia.org/wiki/Coronavirus_Australia
# 64148447 https://en.wikipedia.org/wiki/PPE_Portrait_project
# 63280866 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Pakistan
# 67819031 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_July_2021
# 63370492 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe
# 63254676 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Finland
# 63601740 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_naval_ships
# 63934082 https://en.wikipedia.org/wiki/Covid-Organics
# 63365851 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guatemala
# 63365028 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Papua_New_Guinea
# 63628033 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_domestic_violence
# 67731326 https://en.wikipedia.org/wiki/Sotrovimab
# 63136490 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_United_States
# 63294337 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Oceania
# 68007736 https://en.wikipedia.org/wiki/Aid_and_relief_efforts_during_the_COVID-19_pandemic_in_Malaysia
# 62785398 https://en.wikipedia.org/wiki/2020_Metro_Manila_Summer_Film_Festival
# 2838286 https://en.wikipedia.org/wiki/Grand_Princess
# 63728510 https://en.wikipedia.org/wiki/We_Are_Warriors
# 66561327 https://en.wikipedia.org/wiki/EpiVacCorona
# 63422087 https://en.wikipedia.org/wiki/Edward_C._Allworth_Veterans%27_Home
# 63827000 https://en.wikipedia.org/wiki/Immunity_passport
# 63217011 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Spain
# 68029784 https://en.wikipedia.org/wiki/Hopin_(software)
# 63362222 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Gabon
# 67030365 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Morocco
# 68504378 https://en.wikipedia.org/wiki/IVX-411
# 63688345 https://en.wikipedia.org/wiki/Covid_Act_Now
# 63400209 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Barbados
# 63441669 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_food_industry
# 66073502 https://en.wikipedia.org/wiki/V451_vaccine
# 65797150 https://en.wikipedia.org/wiki/Pfizer%E2%80%93BioNTech_COVID-19_vaccine
# 63272036 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Iceland
# 63612268 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_environment
# 67030150 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Algeria
# 63645596 https://en.wikipedia.org/wiki/Trixie_and_Katya_Save_the_World
# 66794278 https://en.wikipedia.org/wiki/2020_NAB_League_season
# 68602473 https://en.wikipedia.org/wiki/Noora_(vaccine)
# 66339084 https://en.wikipedia.org/wiki/2020_United_States_presidential_primary_elections
# 62622700 https://en.wikipedia.org/wiki/2020_Cannes_Film_Festival
# 63368430 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Northern_Cyprus
# 67079102 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Senegal
# 274584 https://en.wikipedia.org/wiki/RV_Polarstern
# 65243398 https://en.wikipedia.org/wiki/Lego_Super_Mario
# 63926963 https://en.wikipedia.org/wiki/Economic_impact_of_the_COVID-19_pandemic
# 68526259 https://en.wikipedia.org/wiki/Virtual_audience
# 67189291 https://en.wikipedia.org/wiki/SCB-2019
# 67400243 https://en.wikipedia.org/wiki/Corona_Virus_Alert_(song)
# 66732331 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_Republic_of_Ireland
# 61161680 https://en.wikipedia.org/wiki/E3_2020
# 63683133 https://en.wikipedia.org/wiki/COVIDSafe
# 65969519 https://en.wikipedia.org/wiki/J%27imagine
# 64327079 https://en.wikipedia.org/wiki/Food_security_during_the_COVID-19_pandemic
# 67294290 https://en.wikipedia.org/wiki/HGC019
# 63293886 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Georgia_(country)
# 64415092 https://en.wikipedia.org/wiki/Coronavirus_breathalyzer
# 63261355 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Indonesia
# 63488567 https://en.wikipedia.org/wiki/ID2020
# 68613868 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Chile
# 63893846 https://en.wikipedia.org/wiki/Mikki_Willis
# 63142870 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_cruise_ships
# 63532863 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_cannabis_industry
# 65338919 https://en.wikipedia.org/wiki/Good_Job_(song)
# 63887528 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Ossetia
# 63639094 https://en.wikipedia.org/wiki/UN_COVID-19_Supply_Chain_Task_Force
# 66054345 https://en.wikipedia.org/wiki/Christmas_Saves_the_Year
# 68690905 https://en.wikipedia.org/wiki/Pasteurcovac
# 67630896 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Germany
# 63351709 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Honduras
# 58667436 https://en.wikipedia.org/wiki/Badlands_(San_Francisco)
# 65655005 https://en.wikipedia.org/wiki/2020%E2%80%9321_NCAA_football_bowl_games
# 63369676 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_French_Polynesia
# 63366076 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Seychelles
# 63365006 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Syria
# 67006659 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Zimbabwe
# 63451661 https://en.wikipedia.org/wiki/Indian_state_government_responses_to_the_COVID-19_pandemic
# 67188057 https://en.wikipedia.org/wiki/ImmunityBio_COVID-19_vaccine
# 66328752 https://en.wikipedia.org/wiki/2020_Azerbaijani_protests
# 63313195 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Togo
# 68602463 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Serbia
# 65837391 https://en.wikipedia.org/wiki/Maskne
# 66938719 https://en.wikipedia.org/wiki/Chloroquine_and_hydroxychloroquine_during_the_COVID-19_pandemic
# 66389098 https://en.wikipedia.org/wiki/Investigations_into_the_origin_of_COVID-19
# 63858236 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Lesotho
# 63216936 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_United_Kingdom
# 65430430 https://en.wikipedia.org/wiki/Do_What_You_Can
# 63272798 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Romania
# 63359356 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Trinidad_and_Tobago
# 63366667 https://en.wikipedia.org/wiki/Political_impact_of_the_COVID-19_pandemic
# 64109572 https://en.wikipedia.org/wiki/Sancaktepe_Prof._Dr._Feriha_%C3%96z_Emergency_Hospital
# 63641992 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_LGBT_community
# 63025280 https://en.wikipedia.org/wiki/Evacuations_related_to_the_COVID-19_pandemic
# 63364321 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Antigua_and_Barbuda
# 68247113 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Bosnia_and_Herzegovina
# 63364006 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sudan
# 63884873 https://en.wikipedia.org/wiki/Painting_for_Saints
# 65254781 https://en.wikipedia.org/wiki/La_Colonie_(Art_Space)
# 66586562 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Russia
# 66426614 https://en.wikipedia.org/wiki/Deployment_of_COVID-19_vaccines
# 65300947 https://en.wikipedia.org/wiki/2020_Toyota_200
# 63366017 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Angola
# 67036912 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Cape_Verde
# 63366059 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guinea-Bissau
# 60663941 https://en.wikipedia.org/wiki/2020_World_Rally_Championship
# 66402396 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_India
# 66673450 https://en.wikipedia.org/wiki/Security_preparations_for_the_inauguration_of_Joe_Biden
# 63464189 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_video_game_industry
# 63274628 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Argentina
# 63649545 https://en.wikipedia.org/wiki/Institute_for_Health_Metrics_and_Evaluation_COVID_model
# 63696174 https://en.wikipedia.org/wiki/Digital_contact_tracing
# 63560678 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Donetsk_People%27s_Republic
# 65418862 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_February_2021
# 65934402 https://en.wikipedia.org/wiki/Heal_(Southeast_Asian_artists_song)
# 66504480 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Australia
# 64182719 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_children
# 63289321 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Africa
# 64295955 https://en.wikipedia.org/wiki/Jump_Rope_Challenge
# 55607432 https://en.wikipedia.org/wiki/2020_Republican_National_Convention
# 65746712 https://en.wikipedia.org/wiki/COVID-19_protests_in_the_United_Kingdom
# 65908745 https://en.wikipedia.org/wiki/Ratatouille_the_Musical
# 63390797 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_religion
# 63276898 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Belarus
# 65365781 https://en.wikipedia.org/wiki/COVAX
# 63599664 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Artsakh
# 63378621 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_El_Salvador
# 67276824 https://en.wikipedia.org/wiki/MVC_COVID-19_vaccine
# 54528821 https://en.wikipedia.org/wiki/2020_G20_Riyadh_summit
# 63906962 https://en.wikipedia.org/wiki/Philippine_government_response_to_the_COVID-19_pandemic
# 63811664 https://en.wikipedia.org/wiki/COVID-19_Employer_Refund_Scheme
# 67225630 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Bhutan
# 61764043 https://en.wikipedia.org/wiki/Ring_Fit_Adventure
# 64777770 https://en.wikipedia.org/wiki/Quarantine_(Blink-182_song)
# 65277560 https://en.wikipedia.org/wiki/Operation_Moonshot
# 63366071 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mozambique
# 63627644 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_tourism
# 67828251 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Sri_Lanka
# 63683406 https://en.wikipedia.org/wiki/JobKeeper
# 62705243 https://en.wikipedia.org/wiki/2021_World_Rally_Championship
# 63364925 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Malawi
# 63444808 https://en.wikipedia.org/wiki/Ghen_C%C3%B4_Vy
# 63435456 https://en.wikipedia.org/wiki/Zoom_(software)
# 66958846 https://en.wikipedia.org/wiki/2021_Bolivian_doctors%27_strike
# 68039895 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Fiji
# 68476633 https://en.wikipedia.org/wiki/Safe,_Swift_and_Smart_Passage
# 65059623 https://en.wikipedia.org/wiki/2020_LPL_season
# 68068947 https://en.wikipedia.org/wiki/Great_Resignation
# 63260687 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bahrain
# 38097022 https://en.wikipedia.org/wiki/The_Stanley_Parable
# 63609435 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Easter_Island
# 65930696 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_the_United_States
# 67349594 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Croatia
# 67894241 https://en.wikipedia.org/wiki/COVI-VAC_(U.S._COVID-19_vaccine)
# 65830161 https://en.wikipedia.org/wiki/UK_Rapid_Test_Consortium
# 65418863 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_March_2021
# 63327841 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Brunei
# 69128665 https://en.wikipedia.org/wiki/House_Party_(Super_Junior_song)
# 64760870 https://en.wikipedia.org/wiki/Senapura_Rehabilitation_Centre
# 31757223 https://en.wikipedia.org/wiki/The_Parsonage_Garden_at_Nuenen
# 65562123 https://en.wikipedia.org/wiki/Guava_Lamp
# 66508327 https://en.wikipedia.org/wiki/International_reactions_to_the_COVID-19_pandemic_in_Italy
# 64635178 https://en.wikipedia.org/wiki/International_aid_related_to_the_COVID-19_pandemic
# 63055098 https://en.wikipedia.org/wiki/COVID-19_misinformation
# 67453426 https://en.wikipedia.org/wiki/Antivirals_Taskforce_(UK)
# 63300608 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Slovakia
# 18890985 https://en.wikipedia.org/wiki/Malaysia_Agro_Exposition_Park_Serdang
# 67281144 https://en.wikipedia.org/wiki/Marea_(We%27ve_Lost_Dancing)
# 63366054 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Eswatini
# 65762043 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_the_United_Kingdom
# 68525295 https://en.wikipedia.org/wiki/Tixagevimab/cilgavimab
# 63358779 https://en.wikipedia.org/wiki/Flattening_the_curve
# 64598482 https://en.wikipedia.org/wiki/Happy_Anywhere
# 67278807 https://en.wikipedia.org/wiki/Chinese_Academy_of_Medical_Sciences_COVID-19_vaccine
# 67013709 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_United_States
# 65043140 https://en.wikipedia.org/wiki/COVID-19_anti-lockdown_protests_in_New_Zealand
# 63630677 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_long-term_care_facilities
# 66948202 https://en.wikipedia.org/wiki/COVID-19_testing_in_the_Republic_of_Ireland
# 66326404 https://en.wikipedia.org/wiki/INDYCAR_iRacing_Challenge
# 67631900 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Kazakhstan
# 63945131 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_healthcare_workers
# 67994634 https://en.wikipedia.org/wiki/2021_Sri_Lankan_economic_crisis
# 66978482 https://en.wikipedia.org/wiki/ZyCoV-D
# 65660124 https://en.wikipedia.org/wiki/Ghanaian_government_response_to_the_COVID-19_pandemic
# 63113361 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Philippines
# 63216759 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_France
# 68620427 https://en.wikipedia.org/wiki/47th_Telluride_Film_Festival
# 63364122 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Kosovo
# 65995815 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_ICU_capacity
# 67009566 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_migration
# 63222928 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_North_America
# 65724585 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_November_2020
# 63482263 https://en.wikipedia.org/wiki/Operation_Broadshare
# 68587138 https://en.wikipedia.org/wiki/COVID-19_vaccine_hesitancy_in_the_United_States
# 63765505 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_hospitals
# 66232670 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Bulgaria
# 63354085 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Senegal
# 61933429 https://en.wikipedia.org/wiki/Microsoft_Flight_Simulator_(2020_video_game)
# 63275617 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Chile
# 64611308 https://en.wikipedia.org/wiki/Eastern_States_Multi-state_Council
# 63277046 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Ukraine
# 63366081 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Zambia
# 66243733 https://en.wikipedia.org/wiki/COVID-19_misinformation_by_governments
# 67485313 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_South_Korea
# 63520128 https://en.wikipedia.org/wiki/Strikes_during_the_COVID-19_pandemic
# 63354091 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Burkina_Faso
# 61610792 https://en.wikipedia.org/wiki/46th_G7_summit
# 66976335 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_South_Africa
# 67270412 https://en.wikipedia.org/wiki/BriLife
# 67381531 https://en.wikipedia.org/wiki/COVID-19_breakthrough_infection
# 68832274 https://en.wikipedia.org/wiki/Nigerian_government_response_to_the_COVID-19_pandemic
# 63621509 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_performing_arts
# 63346188 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Tunisia
# 63708366 https://en.wikipedia.org/wiki/Charitable_activities_related_to_the_COVID-19_pandemic
# 13707910 https://en.wikipedia.org/wiki/Homeoprophylaxis
# 67025627 https://en.wikipedia.org/wiki/Twindemic
# 64038918 https://en.wikipedia.org/wiki/CovidSim
# 63881567 https://en.wikipedia.org/wiki/Whisper_Tracing_Protocol
# 64598656 https://en.wikipedia.org/wiki/Fabunan_Antiviral_Injection
# 63566901 https://en.wikipedia.org/wiki/Lockdown_Blues
# 63277990 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Estonia
# 67791457 https://en.wikipedia.org/wiki/TAK-919
# 63272144 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Lebanon
# 56624269 https://en.wikipedia.org/wiki/2020_NFL_Draft
# 32093273 https://en.wikipedia.org/wiki/BRP_Ang_Pangulo_(AT-25)
# 63354087 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Ivory_Coast
# 64630786 https://en.wikipedia.org/wiki/Indian_government_response_to_the_COVID-19_pandemic
# 65296793 https://en.wikipedia.org/wiki/COVID-19_testing_in_the_United_States
# 64530138 https://en.wikipedia.org/wiki/Kandakadu_Treatment_and_Rehabilitation_Centre
# 63273278 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saudi_Arabia
# 66301348 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_Philippines
# 332416 https://en.wikipedia.org/wiki/Dexamethasone
# 63734774 https://en.wikipedia.org/wiki/Wikipedia_coverage_of_the_COVID-19_pandemic
# 39419916 https://en.wikipedia.org/wiki/GeForce_10_series
# 64451057 https://en.wikipedia.org/wiki/2020%E2%80%9321_National_Independent_Soccer_Association_season
# 63365068 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Palau
# 63608864 https://en.wikipedia.org/wiki/Better_Days_(OneRepublic_song)
# 65720446 https://en.wikipedia.org/wiki/Life_Goes_On_(BTS_song)
# 68391132 https://en.wikipedia.org/wiki/ARCT-154
# 67195671 https://en.wikipedia.org/wiki/2021_National_People%27s_Congress
# 67060856 https://en.wikipedia.org/wiki/Vaccine_Maitri
# 65802682 https://en.wikipedia.org/wiki/The_Disney_Holiday_Singalong
# 66601883 https://en.wikipedia.org/wiki/Impact_of_COVID-19_on_neurological,_psychological_and_other_mental_health_outcomes
# 63585221 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic
# 63005351 https://en.wikipedia.org/wiki/Xenophobia_and_racism_related_to_the_COVID-19_pandemic
# 63776799 https://en.wikipedia.org/wiki/Virtual_cinema
# 63769277 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_journalism
# 67044747 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cusco
# 67269840 https://en.wikipedia.org/wiki/BBV154
# 62918424 https://en.wikipedia.org/wiki/Huoshenshan_Hospital
# 66913581 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Malaysia
# 63842033 https://en.wikipedia.org/wiki/Speaking_Moistly
# 63462234 https://en.wikipedia.org/wiki/COVID-19_recession
# 63366724 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Kyrgyzstan
# 67543997 https://en.wikipedia.org/wiki/MRNA-1283
# 63879284 https://en.wikipedia.org/wiki/Hero_(Weezer_song)
# 67493507 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Argentina
# 68221196 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Ukraine
# 88988 https://en.wikipedia.org/wiki/Anosmia
# 66391815 https://en.wikipedia.org/wiki/2021_Overwatch_League_season
# 63526358 https://en.wikipedia.org/wiki/COVID-19_surveillance
# 1992390 https://en.wikipedia.org/wiki/Chatham_Cup
# 63384317 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Kiribati
# 68555668 https://en.wikipedia.org/wiki/Nightstream
# 66306149 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Sweden
# 63289309 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Algeria
# 64392045 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_disc_golf
# 60870605 https://en.wikipedia.org/wiki/Ice_hockey_at_the_2022_Winter_Olympics_%E2%80%93_Men%27s_qualification
# 63366743 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Laos
# 63645137 https://en.wikipedia.org/wiki/I_Believe_That_We_Will_Win_(World_Anthem)
# 65332238 https://en.wikipedia.org/wiki/2021_Rose_Bowl
# 65508154 https://en.wikipedia.org/wiki/Covid_fan_tutte
# 1988214 https://en.wikipedia.org/wiki/The_Epoch_Times
# 64421134 https://en.wikipedia.org/wiki/Acting_for_a_Cause
# 63362360 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Faroe_Islands
# 67632179 https://en.wikipedia.org/wiki/2020%E2%80%932021_global_chip_shortage
# 63567756 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Western_Sahara
# 68750333 https://en.wikipedia.org/wiki/Vaccine_passports_during_the_COVID-19_pandemic
# 65141256 https://en.wikipedia.org/wiki/Georgies
# 64171051 https://en.wikipedia.org/wiki/Next_Generation_EU
# 63364407 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_North_Korea
# 64634061 https://en.wikipedia.org/wiki/Russian_government_response_to_the_COVID-19_pandemic
# 67055625 https://en.wikipedia.org/wiki/ARCT-021
# 66899395 https://en.wikipedia.org/wiki/Zoom_fatigue
# 63453597 https://en.wikipedia.org/wiki/Shortages_related_to_the_COVID-19_pandemic
# 66043446 https://en.wikipedia.org/wiki/Hercules_(nightclub)
# 67036875 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Burkina_Faso
# 63407428 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_London
# 67286405 https://en.wikipedia.org/wiki/Corbevax
# 64792624 https://en.wikipedia.org/wiki/Midwest_Governors_Regional_Pact
# 68833019 https://en.wikipedia.org/wiki/Vietnamese_government_response_to_the_COVID-19_pandemic
# 67101199 https://en.wikipedia.org/wiki/2021_Greek_protests
# 66485074 https://en.wikipedia.org/wiki/Soberana_02
# 66557065 https://en.wikipedia.org/wiki/COVID_fog
# 64790560 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Kurdistan_Region
# 67967188 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Equatorial_Guinea
# 64107435 https://en.wikipedia.org/wiki/2020_Toronto_International_Film_Festival
# 63676221 https://en.wikipedia.org/wiki/Exposure_Notification
# 64380196 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_August_2020
# 66590710 https://en.wikipedia.org/wiki/Come_from_Away_(film)
# 67967179 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Djibouti
# 63509217 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_public_transport
# 63366086 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Uruguay
# 63316879 https://en.wikipedia.org/wiki/COVID-19_lockdowns_in_Italy
# 68896635 https://en.wikipedia.org/wiki/Impacts_of_the_COVID-19_crisis_on_female_education
# 63446562 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_social_media
# 66159982 https://en.wikipedia.org/wiki/Novavax_COVID-19_vaccine
# 66911486 https://en.wikipedia.org/wiki/Moldovan%E2%80%93Romanian_collaboration_during_the_COVID-19_pandemic
# 63606142 https://en.wikipedia.org/wiki/Coronavirus_Expert_Advisory_Group
# 63341569 https://en.wikipedia.org/wiki/2020_Russia%E2%80%93Saudi_Arabia_oil_price_war
# 63364964 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Niger
# 61017442 https://en.wikipedia.org/wiki/Animal_Crossing:_New_Horizons
# 66208983 https://en.wikipedia.org/wiki/ZF2001
# 68442310 https://en.wikipedia.org/wiki/The_Q_(nightclub)
# 68340429 https://en.wikipedia.org/wiki/COVAX-19
# 68597435 https://en.wikipedia.org/wiki/COVID-19_vaccine_clinical_research
# 67019071 https://en.wikipedia.org/wiki/Lianhua_Qingwen
# 63364916 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Greenland
# 67920418 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Spain
# 67248101 https://en.wikipedia.org/wiki/COVID-19_vaccine_distribution_by_country_and_territory
# 49100118 https://en.wikipedia.org/wiki/Judy_Wilyman
# 64332973 https://en.wikipedia.org/wiki/Ultimate_Tennis_Showdown
# 63816035 https://en.wikipedia.org/wiki/Don%27t_Stop...
# 63571861 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Guantanamo_Bay_Naval_Base
# 63355934 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Vincent_and_the_Grenadines
# 65088776 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_September_2020
# 63611878 https://en.wikipedia.org/wiki/Level_of_Concern
# 64409779 https://en.wikipedia.org/wiki/Hospital_El_Salvador
# 66613185 https://en.wikipedia.org/wiki/2020_SANFL_Women%27s_League_season
# 61861326 https://en.wikipedia.org/wiki/2020_European_Le_Mans_Series
# 63281785 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Liechtenstein
# 67427795 https://en.wikipedia.org/wiki/EuCorVac-19
# 63195508 https://en.wikipedia.org/wiki/PREPARE
# 64557026 https://en.wikipedia.org/wiki/If_You_Don%27t_Mask,_You_Don%27t_Get
# 66056960 https://en.wikipedia.org/wiki/Bamlanivimab
# 64046884 https://en.wikipedia.org/wiki/Frugal_Four
# 66125058 https://en.wikipedia.org/wiki/Glossary_of_the_COVID-19_pandemic
# 64145180 https://en.wikipedia.org/wiki/When_Life_Is_Good_Again
# 63215769 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Greece
# 63244299 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Austria
# 64399515 https://en.wikipedia.org/wiki/2020%E2%80%932021_Belarusian_protests
# 63408028 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_New_Caledonia
# 63336523 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Qatar
# 67499398 https://en.wikipedia.org/wiki/Health_Code
# 68425756 https://en.wikipedia.org/wiki/ARCT-165
# 65212280 https://en.wikipedia.org/wiki/Club_Feathers
# 63560672 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Luhansk_People%27s_Republic
# 65414439 https://en.wikipedia.org/wiki/Protests_over_COVID-19_policies_in_Germany
# 63365017 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Namibia
# 66959767 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Russia
# 63423368 https://en.wikipedia.org/wiki/Workplace_hazard_controls_for_COVID-19
# 63775420 https://en.wikipedia.org/wiki/Access_to_COVID-19_Tools_Accelerator
# 63362621 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Ethiopia
# 64327424 https://en.wikipedia.org/wiki/Garib_Kalyan_Rojgar_Abhiyaan
# 45266358 https://en.wikipedia.org/wiki/Tipiracil
# 63178675 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Macau
# 67594746 https://en.wikipedia.org/wiki/Sputnik_Light
# 63489614 https://en.wikipedia.org/wiki/Murder_Most_Foul_(song)
# 63473161 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Transnistria
# 63299729 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Cameroon
# 63370773 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Yemen
# ...
# 63300750 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Slovenia
# 65891895 https://en.wikipedia.org/wiki/Get_Out_My_Head_(Shane_Codd_song)
# 63265538 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_India
# 68017962 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_mainland_China
# 67982885 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_the_Comoros
# 57651994 https://en.wikipedia.org/wiki/Beetlejuice_(musical)
# 18606020 https://en.wikipedia.org/wiki/Camostat
# 63870105 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_American_Samoa
# 64950617 https://en.wikipedia.org/wiki/2020_LCK_season
# 64658610 https://en.wikipedia.org/wiki/2020_State_of_the_Nation_Address_(Philippines)
# 64680327 https://en.wikipedia.org/wiki/Homeschooling_during_the_COVID-19_pandemic
# 63364860 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Libya
# 63678830 https://en.wikipedia.org/wiki/Protests_over_responses_to_the_COVID-19_pandemic
# 63228857 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Brazil
# 63589782 https://en.wikipedia.org/wiki/Gendered_impact_of_the_COVID-19_pandemic
# 65560459 https://en.wikipedia.org/wiki/Kissing_the_Coronavirus
# 63787967 https://en.wikipedia.org/wiki/Iisang_Dagat
# 64719181 https://en.wikipedia.org/wiki/United_Nations_response_to_the_COVID-19_pandemic
# 63364099 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guinea
# 63136305 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Thailand
# 67521166 https://en.wikipedia.org/wiki/Bangavax
# 63694441 https://en.wikipedia.org/wiki/TCN_Protocol
# 67624827 https://en.wikipedia.org/wiki/Claire_Deeks
# 63319438 https://en.wikipedia.org/wiki/COVID-19_vaccine
# 64481081 https://en.wikipedia.org/wiki/Untitled_Anxious_Red_Drawings
# 63272041 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_San_Marino
# 67269270 https://en.wikipedia.org/wiki/GRAd-COV2
# 37369338 https://en.wikipedia.org/wiki/New_normal
# 52320669 https://en.wikipedia.org/wiki/LifeSiteNews
# 64302080 https://en.wikipedia.org/wiki/RECOVERY_Trial
# 66995030 https://en.wikipedia.org/wiki/Regdanvimab
# 66091458 https://en.wikipedia.org/wiki/Covaxin
# 66744144 https://en.wikipedia.org/wiki/Test,_Trace,_Protect
# 63181042 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Europe
# 67029513 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Moldova
# 66463200 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_mainland_China
# 63365082 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Solomon_Islands
# 63966151 https://en.wikipedia.org/wiki/Greetings_from_Isolation
# 68750860 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Svalbard
# 68842953 https://en.wikipedia.org/wiki/Protests_over_COVID-19_policies_in_Israel
# 63281894 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Luxembourg
# 66504992 https://en.wikipedia.org/wiki/2021_Dutch_curfew_riots
# 66115428 https://en.wikipedia.org/wiki/Test_to_Release
# 63136199 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Malaysia
# 64945601 https://en.wikipedia.org/wiki/World_on_Fire_(Daughtry_song)
# 63436865 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_prisons
# 63556332 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Antarctica
# 61618326 https://en.wikipedia.org/wiki/2020_NCAA_Division_I_FBS_football_season
# 47373930 https://en.wikipedia.org/wiki/Canton_of_Val_d%27Oingt
# 63393876 https://en.wikipedia.org/wiki/COVID-19_Solidarity_Response_Fund
# 67877826 https://en.wikipedia.org/wiki/2021_Dublin_riots
# 68109336 https://en.wikipedia.org/wiki/QazCoVac-P
# 65735076 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Japan
# 67115929 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Africa
# 63047099 https://en.wikipedia.org/wiki/Fall_Guys
# 63258096 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Dominican_Republic
# 65526255 https://en.wikipedia.org/wiki/Viral_(Amaranthe_song)
# 67540209 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Bangladesh
# 63790837 https://en.wikipedia.org/wiki/Western_States_Pact
# 63365072 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Samoa
# 66082489 https://en.wikipedia.org/wiki/2021_PCS_season
# 63796991 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_May_2020
# 64664953 https://en.wikipedia.org/wiki/This_Week_in_Virology
# 63362010 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Kenya
# 63560792 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Somaliland
# 67164310 https://en.wikipedia.org/wiki/COVID-19_clusters_in_Australia
# 63366069 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mauritania
# 67242622 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Hungary
# 65863464 https://en.wikipedia.org/wiki/2020_ITTF_Finals
# 63555287 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_April_2020
# 67967191 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Eritrea
# 67043144 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Colombia
# 64549287 https://en.wikipedia.org/wiki/Green_recovery
# 63560826 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Tajikistan
# 63281815 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Lithuania
# 64495562 https://en.wikipedia.org/wiki/July_2020_United_Kingdom_summer_statement
# 63499429 https://en.wikipedia.org/wiki/Mental_health_during_the_COVID-19_pandemic
# 63178596 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Hong_Kong
# 63366020 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Botswana
# 64294164 https://en.wikipedia.org/wiki/Kingdom_Hearts:_Melody_of_Memory
# 63366070 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mauritius
# 63372248 https://en.wikipedia.org/wiki/Financial_market_impact_of_the_COVID-19_pandemic
# 63366018 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Benin
# 63364944 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Somalia
# 67151002 https://en.wikipedia.org/wiki/National_Tutoring_Programme
# 67036568 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Angola
# 64800626 https://en.wikipedia.org/wiki/Sputnik_V_COVID-19_vaccine
# 66221163 https://en.wikipedia.org/wiki/World_Memorial_to_the_Pandemic
# 63370785 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Haiti
# 63439802 https://en.wikipedia.org/wiki/CARES_Act
# 65477948 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_animals
# 63808501 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_June_2020
# 67500634 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Nigeria
# 63665310 https://en.wikipedia.org/wiki/2020_PDC_Home_Tour
# 63613677 https://en.wikipedia.org/wiki/Great_American_Economic_Revival_Industry_Groups
# 69109465 https://en.wikipedia.org/wiki/National_File
# 63281933 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_North_Macedonia
# 66071128 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_crime_in_the_Republic_of_Ireland
# 66503974 https://en.wikipedia.org/wiki/Protests_over_COVID-19_policies_in_Italy
# 67967128 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Cameroon
# 63244125 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Netherlands
# 63315611 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bulgaria
# 66699320 https://en.wikipedia.org/wiki/Bamlanivimab/etesevimab
# 67631343 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Norway
# 67189403 https://en.wikipedia.org/wiki/QazCovid-in
# 66371595 https://en.wikipedia.org/wiki/Pok%C3%A9mon_25th_Anniversary
# 52506938 https://en.wikipedia.org/wiki/Microsoft_Teams
# 64626988 https://en.wikipedia.org/wiki/July_Jobs_Stimulus
# 63304474 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Colombia
# 64023322 https://en.wikipedia.org/wiki/Barracuda_Lounge
# 64198548 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Puntland
# 63300912 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Morocco
# 63824523 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_February_2020
# 62103610 https://en.wikipedia.org/wiki/2019%E2%80%932021_Chilean_protests
# 63804580 https://en.wikipedia.org/wiki/Symptoms_of_COVID-19
# 67184914 https://en.wikipedia.org/wiki/Abdala_(vaccine)
# 63630438 https://en.wikipedia.org/wiki/Bored_In_the_House
# 60634575 https://en.wikipedia.org/wiki/Intellivision_Amico
# 67666854 https://en.wikipedia.org/wiki/Grounded_with_Louis_Theroux
# 63637163 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Cook_Islands
# 63500512 https://en.wikipedia.org/wiki/MusiCares_COVID-19_Relief_Fund
# 64049906 https://en.wikipedia.org/wiki/The_Cock
# 63260725 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Mexico
# 68331624 https://en.wikipedia.org/wiki/Catrgory:Indian_COVID-19_vaccine
# 66791498 https://en.wikipedia.org/wiki/CureVac_COVID-19_vaccine
# 67361886 https://en.wikipedia.org/wiki/Zoom_town
# 63548286 https://en.wikipedia.org/wiki/Clap_for_Our_Carers
# 63594947 https://en.wikipedia.org/wiki/Epidemic_Response_Committee
# 63422845 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Isle_of_Man
# 69045728 https://en.wikipedia.org/wiki/2021_global_supply_chain_crisis
# 63562819 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Abkhazia
# 68771298 https://en.wikipedia.org/wiki/Paradise_(Kill_the_Silence)
# 66637128 https://en.wikipedia.org/wiki/2020_WAFL_Women%27s_season
# 63969760 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Navajo_Nation
# 63531353 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_March_2020
# 65082081 https://en.wikipedia.org/wiki/Panic_(From_Ashes_to_New_song)
# 63262215 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Portugal
# 63273458 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Bosnia_and_Herzegovina
# 63348169 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Montenegro
# 67466645 https://en.wikipedia.org/wiki/Razi_Cov_Pars
# 66168599 https://en.wikipedia.org/wiki/Consolidated_Appropriations_Act,_2021
# 68534951 https://en.wikipedia.org/wiki/Manila_COVID-19_Field_Hospital
# 63939389 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Portugal
# 63329395 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Guernsey
# 63366586 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Suriname
# 66048484 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Thailand
# 2460052 https://en.wikipedia.org/wiki/Javits_Center
# 65944486 https://en.wikipedia.org/wiki/Hug_tunnel
# 67371669 https://en.wikipedia.org/wiki/COVID-19_vaccination_in_Greece
# 68331598 https://en.wikipedia.org/wiki/Catrgory:Indian_COVID-19_vaccines
# 67932079 https://en.wikipedia.org/wiki/China_COVID-19_cover-up_allegations
# 63573768 https://en.wikipedia.org/wiki/Withdrawal_of_United_States_troops_from_Iraq_(2020%E2%80%932021)
# 54450713 https://en.wikipedia.org/wiki/Protests_against_Rodrigo_Duterte
# 65130522 https://en.wikipedia.org/wiki/Paradise_(nightclub)
# 68677280 https://en.wikipedia.org/wiki/Soberana_Plus
# 63631542 https://en.wikipedia.org/wiki/Face_masks_during_the_COVID-19_pandemic
# 63127009 https://en.wikipedia.org/wiki/Ice_hockey_at_the_2022_Winter_Olympics_%E2%80%93_Women%27s_qualification
# 64540171 https://en.wikipedia.org/wiki/Fast_Grants
# 68153320 https://en.wikipedia.org/wiki/Draft:Vaccine_bond
# 65511723 https://en.wikipedia.org/wiki/KRI_Semarang_(594)
# 63635398 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_crime
# 63695683 https://en.wikipedia.org/wiki/Convidecia
# 68714331 https://en.wikipedia.org/wiki/COVID-19_vaccine_misinformation_and_hesitancy
# 63039926 https://en.wikipedia.org/wiki/COVID-19_pandemic_cases
# 63751472 https://en.wikipedia.org/wiki/COVID-19_Pandemic_Unemployment_Payment
# 66141405 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_popular_culture
# 63480383 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Saint_Kitts_and_Nevis
# 63344447 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Nepal
# 66139472 https://en.wikipedia.org/wiki/Valneva_COVID-19_vaccine
# 65845227 https://en.wikipedia.org/wiki/Pandemic_fatigue
# 66346452 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Federated_States_of_Micronesia
# 63642091 https://en.wikipedia.org/wiki/Global_Pride
# 64744778 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_December_2020
# 37017979 https://en.wikipedia.org/wiki/Plague_Inc.
# 66431202 https://en.wikipedia.org/wiki/2021_European_Le_Mans_Series
# 63821674 https://en.wikipedia.org/wiki/2020_The_Real_Heroes_400
# 63397600 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_East_Timor
# 67123375 https://en.wikipedia.org/wiki/Vaccine_line_jumping
# 63364001 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Venezuela
# 69053934 https://en.wikipedia.org/wiki/WHO_Hub_for_Pandemic_and_Epidemic_Intelligence
# 65007833 https://en.wikipedia.org/wiki/Sekaij%C5%AB_no_Rinjin_yo
# 65911967 https://en.wikipedia.org/wiki/New_Hope_Club_Virtual_World_Tour
# 2532674 https://en.wikipedia.org/wiki/CFB_Trenton
# 63478388 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_science_and_technology
# 63636316 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_the_military
# 63262762 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Andorra
# 64118463 https://en.wikipedia.org/wiki/Novel_Coronavirus_Expert_Meeting
# 62508050 https://en.wikipedia.org/wiki/Taylor_Winterstein
# 63647244 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_international_relations
# 64244400 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_India
# 67189736 https://en.wikipedia.org/wiki/VBI-2902
# 64192678 https://en.wikipedia.org/wiki/Face_masks_during_the_COVID-19_pandemic_in_the_United_States
# 63430824 https://en.wikipedia.org/wiki/COVID-19_drug_repurposing_research
# 63366056 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Gambia
# 67276945 https://en.wikipedia.org/wiki/UB-612
# 63948123 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Germany
# 64958366 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Australia
# 63313047 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Moldova
# 66409096 https://en.wikipedia.org/wiki/CoVLP
# 64624687 https://en.wikipedia.org/wiki/Epiphany_(Taylor_Swift_song)
# 63262736 https://en.wikipedia.org/wiki/Travel_during_the_COVID-19_pandemic
# 66456258 https://en.wikipedia.org/wiki/2021_LEC_season
# 64349520 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Poland
# 64360653 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_July_2020
# 63843654 https://en.wikipedia.org/wiki/Magnus_Carlsen_Invitational
# 63750595 https://en.wikipedia.org/wiki/Living_in_a_Ghost_Town
# 41884787 https://en.wikipedia.org/wiki/Frozen_(musical)
# 63842737 https://en.wikipedia.org/wiki/2020_National_People%27s_Congress
# 64003195 https://en.wikipedia.org/wiki/Apps_to_analyse_COVID-19_sounds
# 62257865 https://en.wikipedia.org/wiki/UFC_on_ESPN:_Overeem_vs._Harris
# 63362225 https://en.wikipedia.org/wiki/Human_rights_issues_related_to_the_COVID-19_pandemic
# 63381322 https://en.wikipedia.org/wiki/I%27m_Ready_(Sam_Smith_and_Demi_Lovato_song)
# 68199446 https://en.wikipedia.org/wiki/Draft:COVID-19_vaccination_mandates_in_the_United_States
# 67911325 https://en.wikipedia.org/wiki/INO-4802
# 65467447 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_October_2020
# 63366035 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Equatorial_Guinea
# 65480227 https://en.wikipedia.org/wiki/Impact_of_the_COVID-19_pandemic_on_people_with_disabilities
# 63113319 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Singapore
# 68841583 https://en.wikipedia.org/wiki/Frontline_Part_Two
# 63560856 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sevastopol
# 67818951 https://en.wikipedia.org/wiki/Responses_to_the_COVID-19_pandemic_in_June_2021
# 63636485 https://en.wikipedia.org/wiki/BlueTrace
# 63801738 https://en.wikipedia.org/wiki/Open_the_States
# 63631325 https://en.wikipedia.org/wiki/Claws_(song)
# 63808182 https://en.wikipedia.org/wiki/Mask,_Gloves,_Soap,_Scrubs
# 63866435 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Wallis_and_Futuna
# 64063338 https://en.wikipedia.org/wiki/The_2.6_Challenge
# 63264158 https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Ireland
# 63634124 https://en.wikipedia.org/wiki/COVID-19_pandemic_on_Grand_Princess
# 66546768 https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Argentina

# %%
#wikiPageCategories[0:10]

wikiPageError[0:5]  # solo un error: [['2021-11-26', 68542482], ['2021-11-29', 65225706, 'Page error']]

wikiPageCategories[0:5] #
wikiPageCategoriesDF = pd.DataFrame(wikiPageCategories, columns=['date', 'wikipageID', 'category']).to_csv('wikiPageCategories2.csv')
wikiPageWikiProjects[0:5] # ptable
wikiPageWikiProjectsDF = pd.DataFrame(wikiPageWikiProjects, columns=['date', 'wikipageID', 'project', 'link', 'linkName']).to_csv('wikiPageWikiProjects2.csv')

# %%
wikiPageTOCDF = pd.DataFrame(wikiPageTOC, columns=['date', 'wikipageID', 'toclevel', 'level', 'line', 'number', 'index', 'fromtitle', 'anchor'])
#wikiPageTOCDF[wikiPageTOCDF['line'].str.contains("<i>", case=False)]

# Clean html tag:
wikiPageTOCDF["line"].replace({"<i>": "", "</i>": ""}, inplace=True)

# %%
wikiPageTOCDF.to_csv('wikiPageTOC2.csv')

# %% [markdown]
# # ********************Desde aquí ejecutar y cargar wikiPageTOC desde wikiPageTOC.csv

# %%
import pandas as pd
wikiPageTOC =pd.read_csv('wikiPageTOC2.csv').values.tolist()
wikiPageTOC[0:5]
# Out:
# [[0,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in Africa',
#   '1',
#   '1',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_Africa'],
#  [1,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in the Americas',
#   '2',
#   '2',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_the_Americas'],
#  [2,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in the Eastern Mediterranean',
#   '3',
#   '3',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_the_Eastern_Mediterranean'],
#  [3,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in Europe',
#   '4',
#   '4',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_Europe'],
#  [4,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in South and Southeast Asia',
#   '5',
#   '5',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_South_and_Southeast_Asia']]

# %%
sections = ['See also', 'REFERENCES','External links', 'Further reading', 'Notes','Bibliography', 'Filmography%', 'Timeline%', 'Statistics%', '%2020',
            '%2021', 'Release history', 'Charts', 'Gallery'] # , 'Timeline', 'Statistics', '2020', '2021']
#page LIKE 'http://en.wikipedia.org/wiki/COVID-19_pandemic_in%')
#AND page NOT LIKE '%Timeline%' AND page NOT LIKE '%/Responses_to%']

def verify2(c):
    
    for l in sections:
        #print(l, c.lower)
        if l.lower() in c.lower():
            return False
    return True


#wikiPageTOC = wikiPageTOCDF.values.tolist() # 17034
lenT = len(wikiPageTOC)
tocSel = [wikiPageTOC[c] for c in range(lenT) if verify2(wikiPageTOC[c][5]) and 'Song' not in wikiPageTOC[c][7] and 'Statistics' not in wikiPageTOC[c][7] and 'Template:' not in wikiPageTOC[c][7]]
print(len(tocSel)) # 14878, 11806(sin 2020, 2021, Timeline y Statistics)


#wikiPageTOCDF['line'].str.contains("<i>", case=False)]
# Out:
# 14878

# %%
wikiPageTOC2[20:30]
print(len(tocSel)) # 14972 a 14675 quitando temprates y statistics. 14661
tocSel[0:1]
# Out:
# 14878
# [[0,
#   '2021-12-02',
#   66453368,
#   1,
#   2,
#   'Reactions and measures in Africa',
#   '1',
#   '1',
#   'Responses_to_the_COVID-19_pandemic_in_April_2021',
#   'Reactions_and_measures_in_Africa']]

# %% [markdown]
# <b> c. Cleaning sections and pages </b>
#
# Identify sections of the pages with textual content:

# %%
wikiPageTOC_Filtered = [] # tocSelected
wikiPageTOC_Grouped  = [] # tocGrouped
wikiPageTOC_Aux  = [] # tocAux
wikiTOCByPage = []  # tocCpages *** 
wikiPageSections = []
wIKIPAGESECTIONCONTENT  = [] # tocContent  ****
#wIKIPAGESECTIONLINKS  = [] # tocContentLinks *****
wikiPageSectionLinks = []
wikiPageError = []

# %% [markdown]
# ## 3.  Get content from each section

# %%
#tocSelDF = pd.DataFrame(tocSel, columns= ['i', 'date', 'wikipageID', 'toclevel', 'level', 'line', 'number', 'index', 'fromtitle', 'anchor'])

# %%
# Get section:
#from bd import BDdatos
from datetime import date
import wikipedia
from bs4 import BeautifulSoup
import re

#db = BDdatos()
#con = db.conectar()

def getPageID(l1, l2):
    print("Downloading data from Wikipedia:")
    if l1:
        idP = tocSel[l1][2]
    else:
        idP = tocSel[0][2]
    toc = []
    for l in range(l1, l2): #range(len(tocSel)):
        if idP != tocSel[l][2]:
            print(l, '>>', idP)
            #print(toc)
            getSection(idP, toc)
            toc = []
        toc.append(tocSel[l][5])
        idP = tocSel[l][2]
            #print(tocSel[l][1], toc)    

def getSection(pageid, toc):
    try:
        page = wikipedia.WikipediaPage(pageid=str(pageid))
        print(page.url)
    
        # Part 2: extraction of the content by sections:
        
        List_contentByTOC = []  
        t = 0
        head = 0
        c = 0
        if len(toc) > 0:
            contentByTOC = toc[t] # Primera sección
            lenTOC = len(toc)  # menos 1
        else:
            contentByTOC = 'head'
            lenTOC = len(toc) + 1 # sin más
        #print(lenTOC, toc)
        content = page.content
        splitText = []
        a, *l = re.split('==+', content) 
        if len(a) > 1:
            splitText.append(a)
        splitText = splitText + l 
    
        # Clean from empty strings:
        splitText = [x for x in splitText if x.strip() and x != '\n\n\n' and x != '\n\n']
        #print(splitText)
        if contentByTOC != splitText[c].strip().replace('=', ''): # 
            List_contentByTOC.append(['head', 0, splitText[c].strip()])
            head = 1
            c = c + 1
        if len(toc) > 1:
            m = c
        #print(toc)
        #print('---------------------------')

            r = c
        #print(len(splitText))
            while t < lenTOC:
            
            # desde aquí:
                match = False
                contentByTOC = toc[t] # here toc[t+1], toc[t] (cmabio2)
            
                while not(match):
                    #print(m, contentByTOC)
                    #print(splitText[m].strip())
                    if verify2(splitText[m].strip()): # verify2(splitText[m].strip().replace(',', '-')):
                
                        if toc[t].strip().replace(',', '-') == splitText[m].strip().replace(',', '-') and splitText[m+1].strip() not in toc: # here: m + 1, splitText[m] (cmabio2)
                            List_contentByTOC.append([contentByTOC, t, splitText[m+1].strip().replace('=\n', '')]) # here: m + 1, m (cmabio2)
                            t = t + 1
                            match = True
                        else:
                            #print(m, contentByTOC, splitText[m].strip().replace(',', '-')) # .replace(',', '-'))
                            if toc[t].strip().replace(',', '-') == splitText[m].strip().replace(',', '-') and splitText[m+1].strip() in toc: 
                                match = True
                                t = t + 1
                        
                    m = m + 1
                    #print(4*'-', splitText[m].strip())
                #print(List_contentByTOC)
            # hasta aquí:
        
        # Insert into the DB:
        for l in List_contentByTOC:
            wikiPageSections.append([date.today().strftime("%Y-%m-%d"), pageid, l[0], l[1], l[2]])
        
        # Part 3: getting urls by section:
        List_linksByTOC = []
        html = page.html()
        spllitp = html.split('title="Edit section: ')
        ls = len(toc) + 1
        li = 0
        if head:
            soupS = BeautifulSoup(spllitp[0],"html.parser")
            links = soupS.find_all(name='a')
            li = 1
            for i in links:
                try:
                    url = i['href']
                    if 'wiki' in url and 'File:' not in url and 'Wikipedia:' not in url and 'Help:' not in url:
                        List_linksByTOC.append(['head', 0, i.text, url])
                except:
                    continue
        for s in range(li, ls):
            #print('\n\n\n >>>>>', s)
            soupS = BeautifulSoup(spllitp[s],"html.parser")
            links = soupS.find_all(name='a')
            sec = toc[s-1] # *** [0]
            for i in links:
                try:
                    url = i['href']
                    if 'wiki' in url and 'File:' not in url and 'Wikipedia:' not in url and 'Help:' not in url:
                        List_linksByTOC.append([sec, s, i.text, url])
                except:
                    continue
        #print([row for row in List_linksByTOC[220:250]])
        
        unique_linksByTOC = [list(item) for item in set(tuple(row) for row in List_linksByTOC)] #  [list(item) for item in set(tuple(row) for row in List_linksByTOC)]
    
        for l in unique_linksByTOC:
            #print(l[0], l[1], l[2], l[3])
            wikiPageSectionLinks.append([date.today().strftime("%Y-%m-%d"), pageid, l[0], l[1], l[2], l[3]])
    #print(List_contentByTOC)
    except:
        print("Error")
        wikiPageError.append([date.today().strftime("%Y-%m-%d"), pageid, "Page error", page.url])
        #continue


# To RUN:                
#Only for test: getSection(1, "High_Point_Market", "High Point Market", ['History', 'Furniture Cluster/Niche'])

# %%
getPageID(14860, 14878) # 53 (problema). 57:101, 437, 490  14675  # 384,393 >> 65225706, https://en.wikipedia.org/wiki/OK_Not_to_Be_OK
#wikiPageSections[0:22]
#wikiPageSections[37:44]
#tocSel[354:384] # 63346138


#329 >> 68389568 >> https://en.wikipedia.org/wiki/Love_is_not_tourism

#329 >> 63346121 >> COVID-19_pandemic_in_Peru

#len(tocSel) # 14972

# 589 >> 63178636, https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Taiwan, 42 sections

# errores:
# 66 >> 63648639 >> https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Brazil
#1056 >> 64008008 >> https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_Play-Offs
# 1148 >> 63300653 >> https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Africa
# 1444 >> 62750956 >> https://en.wikipedia.org/wiki/COVID-19_pandemic
# 1521 >> 65682288 >> https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_3
# 1599 >> 48410011 >> https://en.wikipedia.org/wiki/2020_United_States_presidential_election
# 1611 >> 68076170 >> https://en.wikipedia.org/wiki/Proximity_chat
# Out:
# Downloading data from Wikipedia:
# 14869 >> 63634124
# https://en.wikipedia.org/wiki/COVID-19_pandemic_on_Grand_Princess

# %%
len(wikiPageError)
wikiPageError[0:5]
# Out:
# [['2021-12-03',
#   63648639,
#   'Page error',
#   'https://en.wikipedia.org/wiki/Statistics_of_the_COVID-19_pandemic_in_Brazil'],
#  ['2021-12-03',
#   63272917,
#   'Page error',
#   'https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Sri_Lanka'],
#  ['2021-12-03',
#   65060446,
#   'Page error',
#   'https://en.wikipedia.org/wiki/Artificial_crowd_noise'],
#  ['2021-12-03',
#   64008008,
#   'Page error',
#   'https://en.wikipedia.org/wiki/2020_PDC_Home_Tour_Play-Offs'],
#  ['2021-12-03',
#   63300653,
#   'Page error',
#   'https://en.wikipedia.org/wiki/COVID-19_pandemic_in_South_Africa']]

# %% [markdown]
# ## 4.  Get information about links included in the section's content (from Wikidata)
#
# <b> a. Identify unique links to get data </b>

# %%
from bd import BDdatos

db = BDdatos()
con = db.conectar()


annLinkIDs = 'WikiAnnotationLinksIDs'  # Unique links
annMetadata = 'WikiAnnotationMetadata'

cur = con.cursor()

# Get unique links
cur.execute("""CREATE TABLE """ + annLinkIDs + """  (id INT AUTO_INCREMENT PRIMARY KEY) AS 
SELECT DISTINCT link, count(*) AS freq FROM """ + tocContentLinks + """
WHERE link LIKE '%/wiki/%' GROUP BY link HAVING count(*) > 3; """)


# Create table for metadata:

cur.execute("""CREATE TABLE """ + annMetadata + """ (
  `date` date,
  `link` TEXT CHARACTER SET utf8,
  `url` TEXT CHARACTER SET utf8,
  `title` TEXT CHARACTER SET utf8,  
  `pageid` VARCHAR(20) CHARACTER SET utf8 DEFAULT NULL,
  `revid` VARCHAR(20) CHARACTER SET utf8 DEFAULT NULL,
  lastUpdate date,
  `summary` LONGTEXT CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci
) ENGINE=INNODB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_general_ci;""")

db.saveDB(con)
db.closeDB(con)

# %%
annLinkIDs = 'WikiAnnotationLinksIDs'  # Unique links
annMetadata = 'WikiAnnotationMetadata'
URL = "https://en.wikipedia.org/w/api.php"
S = requests.Session()
def getLastUpdate(pageid):
    pageid = str(pageid)
    PARAMS = {'action':'query',
        'pageids': pageid,
        'prop':'revisions',
        'rvprop':'ids|flags|timestamp|userid|user|size|comment|tags',
        'rvlimit':'100',
        "format": "json"
    }
    req = S.get(url=URL, params=PARAMS)
    data = req.json()
    date = data["query"]['pages'][pageid]['revisions'][0]['timestamp'] 
    return date

# %% [markdown]
# <b> b. Gathering the metadata from Wikipedia </b>

# %%
from bd import BDdatos
from datetime import date
import wikipedia
from bs4 import BeautifulSoup
import re
import urllib
import requests

db = BDdatos()
con = db.conectar()

def getAnnotationID(l1, l2):
    cur = con.cursor()
    print("Downloading data:")
    cur = con.cursor() # annLinkIDs 
    cur.execute("""SELECT distinct id, link FROM """ + annLinkIDs + """ where id >""" +str(l1)+' and id <= ' + str(l2) + ' order by id')
    rowList = cur.fetchall()
    for row in rowList:
        idP = row[0]
        urlP = 'http://en.wikipedia.org'+row[1]
        title = urllib.parse.unquote(row[1].replace('/wiki/', ''))
        print(idP, urlP, title)
        if title:
            getPageMetadata(idP, urlP, title, 1)


def getPageMetadata(idP, urlP, title, state):
    try:
        page = wikipedia.WikipediaPage(title=title) 

        ################################################################
        # Part 1: Metadata
        summary = page.summary
        revision_id = page.revision_id
        pageid = page.pageid
        lastUpdate = getLastUpdate(pageid)
        lastUpdate = lastUpdate[0:10]
        db.WikiAnnotationMetadata(db, date.today().strftime("%Y-%m-%d"), urlP, page.url, page.title, pageid, revision_id, lastUpdate, summary, annMetadata)
    except: 
        print("Annotation not found")
        db.WikiPageError(db, date.today().strftime("%Y-%m-%d"), urlP, "Annotation not found", 'WikiPageError')


# TO RUN:
getAnnotationID(9637, 11867)

# %% [markdown]
# <b> c. Integrating data </b>

# %%
from bd import BDdatos

db = BDdatos()
con = db.conectar()


#annLinkIDs = 'WikiAnnotationLinksIDs'  # Unique links
#annMetadata = 'WikiAnnotationMetadata'

cur = con.cursor()

# To create index:
cur.execute("""ALTER TABLE """ + tocContentLinks + """ ADD INDEX (`page` (100));""")
cur.execute("""ALTER TABLE """ + annMetadata + """ ADD INDEX (`link` (100));""")


db.saveDB(con)
db.closeDB(con)

# %% [markdown]
# ## 5.  Filter data not related to COVID-19
#
# ### 9.2  Get content from data repository
#
# ### Buscar las menciones dentro de las secciones/párrafos (phrase matching)
#
# Ahora si lo que quieres es buscar las menciones dentro de las secciones/párrafos, podrías hacer phrase matching basandote en un gazetteer (= lista de términos relevantes para covid), por ejemplo usando spacy:

# %%
# Crear table:

from bd import BDdatos
db = BDdatos()
con = db.conectar()

tableCovid = 'WikiPageSectionCOVID'
tableContent = "WIKIPAGESECTIONCONTENT"
pageIDs = "WikiPagesIDs"

cur = con.cursor()


cur.execute(u"""ALTER TABLE """ + tableContent + """ ADD `idpage` INT  NULL  DEFAULT NULL  AFTER `page`;""")

cur.execute(u"""UPDATE """ + tableContent + """ c LEFT OUTER JOIN """ + pageIDs + """  p
ON c.page = p.wikipageUrl SET c.idpage = p.id""")

cur.execute(u"""CREATE TABLE """ + tableCovid + """ (`date` date,
     page TEXT, section TEXT, idSection INT, idWikidata VARCHAR(50),
     startPos INT, endPos INT, textMatch TEXT);""")

db.saveDB(con)
db.closeDB(con)

# %%
tableCovid = 'WikiPageSectionCOVID'
tableContent = "WIKIPAGESECTIONCONTENT"
pageIDs = "WikiPagesIDs"
mtable = 'WikiPageMetadata'

# %%
COVIDGazetteer

# %%
<b> Requisite </b>: Hasta este punto ya debió estar creado el Gazetter:

# %%
# addingphrase matching

# python -m spacy download en_core_web_sm -> to update  to 2.3.1 version of en_core_web_sm



# Subir archivo de Gazetteer:
import pandas as pd

path = "../QA/data/COVIDGazetter28Feb.csv"
COVIDGazetteer = pd.read_csv(path, sep = "|")
terms = [t for t in COVIDGazetteer["o"]]

#s = COVIDGazetteer[COVIDGazetteer['o'].str.lower() == "coronavirus"].iloc[0]["s"]
#s
#for text in terms:
#    if "COVID-19 pandemic" in text:
#        print(text)


from bd import BDdatos
import codecs
import json
from datetime import date
import spacy
from spacy.matcher import PhraseMatcher

db = BDdatos()
con = db.conectar()

nlp = spacy.load('en_core_web_sm')
matcher = PhraseMatcher(nlp.vocab, attr="LOWER") # First, we initialize the Matcher with a vocab. The matcher must always share the same vocab with the documents it will operate on. We can now call matcher.add() with an ID and our custom pattern. The second argument lets you pass in an optional callback function to invoke on a successful match. For now, we set it to None.

# Only run nlp.make_doc to speed things up
patterns = [nlp.make_doc(text) for text in terms]
matcher.add("TerminologyList", None, *patterns)

tablecontent = 'WIKIPAGESECTIONCONTENT' # _IRQA_FRAGMENTS_FINAL

def getWikipediaFragments(l1, l2):
    cur = con.cursor()
    print("Descargando datos:")
    cur = con.cursor()
    cur.execute("""SELECT DISTINCT idpage, page, sectionID, section section_ori, 
    REPLACE(section, '/', '_') section, sectionId, secText FROM """ + tablecontent + """ WHERE secText != '' AND idpage >""" +str(l1)+' and idpage <= ' + str(l2))
    rowList = cur.fetchall()
    for row in rowList:
        idP = row[0]
        page = row[1]
        idSection = row[2]
        section_ori = row[3]
        section = row[4]
        idSec = row[5]
        doc = row[6]
        doc = nlp(doc)
        matches = matcher(doc)
        print(idP, page, section_ori)
        for match_id, start, end in matches:
            span = doc[start:end]
            if not(COVIDGazetteer[COVIDGazetteer['o'].str.lower() == span.text.lower()].empty):
                idWikidata = COVIDGazetteer[COVIDGazetteer['o'].str.lower() == span.text.lower()].iloc[0]["s"]
                #print(page, section_ori, idSection, idWikidata, start, end, span.text) # The matcher returns a list of (match_id, start, end) tuples – in this case, [('15578876784678163569', 0, 3)], which maps to the span doc[0:3] of our original document. The match_id is the hash value of the string ID “HelloWorld”. To get the string value, you can look up the ID in the StringStore
                db.WikiPageSectionCOVID(db, date.today().strftime("%Y-%m-%d"), page, section_ori, idSection, idWikidata, start, end, span.text, tableCovid)
            
# TO RUN:
getWikipediaFragments(239, 2875) # 2875

# %% [markdown]
# <b> Filter page sections' with covid terms </b>

# %%
from bd import BDdatos
db = BDdatos()
con = db.conectar()

tablefilter = 'WikiPageSectionCOVIDFilter'
tableFinal = "IRQA_FRAGMENTS_FINAL"

cur = con.cursor()

cur.execute(u"""CREATE TABLE """ + tablefilter + """ AS
     SELECT PAGE, IDSECTION, COUNT(DISTINCT idwikidata) AS freqcovid FROM 
     """ + tableCovid + """ GROUP BY PAGE, IDSECTION;""")
    

cur.execute(u"""CREATE TABLE """+ tableFinal + """ AS
    SELECT DISTINCT S.*, lastUpdate FROM """ + tablefilter + """ F
    INNER JOIN """ + tableContent + """ s  
    ON f.page = s.page AND f.idsection = s.sectionid
    LEFT OUTER JOIN """ + mtable + """ M
    ON f.page = m.page;""")
            
db.saveDB(con)
db.closeDB(con)

# %% [markdown]
# <b> Filter content depending of the classification </b>

# %%
from bd import BDdatos
import time, random
db = BDdatos()
con = db.conectar()

from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("/Users/jachicaiza/envs/pyenv/coronabert")
model = AutoModelForSequenceClassification.from_pretrained("/Users/jachicaiza/envs/pyenv/coronabert")

# Retrieve data

# Load Data
import pandas as pd 
from scipy.special import expit     # Use scipy to run a logistic function on the scores (to scale them from 0 to 1)z
from datetime import date

#closeDB(con)
cursor=con.cursor()
cursor.execute(u"""SELECT DISTINCT source, id, page, category, stext FROM QA_DATA_ALL_FINAL 
ORDER BY source, id;""")
areas = cursor.fetchall()
areas = pd.DataFrame(areas)
areas.columns=['source', 'id', 'page', 'category', 'stext']
    
areasT = []

areas.loc[333:334, ["id", "stext"]]
len(areas)

#for i in areas.loc[0:334, ["id", "stext"]].iterrows():
#    print(i[1][0])
#    text = [i[1][1]]
#    print(text)

# Create some input text. This would normally be title plus
# abstract (where available) in a single string
#text = list(areas.loc[0:1, "abstract"])

# %%
for i in areas.loc[0:16100, ['source', 'id', 'page', 'category', 'stext']].iterrows():
    print(i[1][0], i[1][1])
    text = [i[1][4]]
    #print(text)
    # Tokenize it with appropriate padding and truncation
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=500)
    # Run the sequence classication model
    outputs = model(**inputs)
    # Pull out the scores for the first article
    #scores = outputs.logits[0,:].tolist() # new version of transformers
    scores = outputs[0][0,:].tolist()
    scores = expit(scores) # outputs
    # Get the associated labels from the model config and sort them to show the
    # highest scoring topic / article type
    scores_with_labels = [ (s,model.config.id2label[i]) for i,s in enumerate(scores) ]
    #sorted(scores_with_labels, reverse=True)
    ranking = sorted(scores_with_labels, reverse=True)
    n = 0
    time.sleep(6+random.uniform(0, 8))
    #print(ranking)
    for r in ranking:
        n = n + 1
        areasT.append([i[1][0], i[1][1], i[1][2], i[1][3], n, r[0], r[1]])

# %%
import csv 

len(ranking)

fields = ['source', 'id', 'page', 'category', 'position', 'score', 'subject']

with open('Transformer04abr.csv', 'w') as f:
    write = csv.writer(f) 
    write.writerow(fields) 
    write.writerows(areasT)

db.saveDB(con)
db.closeDB(con)

# %% [markdown]
# ### 9.3 Convert  Wikipedia fragments to a text corpus

# %%
from bd import BDdatos
import codecs
import json
from datetime import date

db = BDdatos()
con = db.conectar()
text_path = '../QA/corporaCOVID'

def convertToDoc(l1, l2):
    cur = con.cursor()
    print("Download data:")
    cur = con.cursor()
    cur.execute("""SELECT DISTINCT idpage, page, REPLACE(REPLACE(section, '/', '_'), '#', '_') section,
    sectionId, concat(REPLACE(REPLACE(section, '/', '_'), '#', '_'), '\n', secText) FROM """ 
    + tableFinal + """ WHERE secText != '' AND idpage > """ +str(l1)+ ' and idpage <= ' + str(l2))
    rowList = cur.fetchall()
    for row in rowList:
        idP = row[0]
        page = row[1]
        section = row[2]
        idSec = row[3]
        doc = row[4]
        name = str(idP)+"_"+section+".txt"
        print(name)
        file = open(text_path+"/"+name, 'w')
        try:
            file.write(doc)
        finally:
            file.close()
            
# To run:
convertToDoc(0, 2875)

# %% [markdown]
# ### Agregar respuestas de los QA pairs,
#
# Lo nterior hay que actualizar con la nueva data extraída y correr nuevamente:

# %%
from bd import BDdatos
import codecs
import json
from datetime import date

db = BDdatos()
con = db.conectar()
text_path = '../QA/corporaCOVID'

tpairsQA = 'QAPairsFINAL'

def getWikipediaFraments(l1, l2):
    cur = con.cursor()
    print("Descargando datos:")
    cur = con.cursor()
    cur.execute("""SELECT DISTINCT id, url, source, sourceDate, concat(question, '\n', categories, '\n', answer) text
    FROM """ + tpairsQA + """ WHERE id >""" +str(l1)+' and id <= ' + str(l2))
    rowList = cur.fetchall()
    for row in rowList:
        idP = row[0]
        page = row[1]
        source = row[2]
        sourceDate = row[3]
        doc = row[4]
        name = str(idP)+"_"+source+".txt"
        print(name)
        file = open(text_path+"/"+name, 'w')
        try:
            file.write(doc)
        finally:
            file.close()
            
getWikipediaFraments(0, 1500)

# %% [markdown]
# <b> Join data from all the sources </b>

# %%
from bd import BDdatos
db = BDdatos()
con = db.conectar()

tableUnion = "QA_DATA_ALL_FINAL"
tableQA = "QAPairsFINAL"

cur = con.cursor()

cur.execute(u"""CREATE TABLE """ + tableUnion + """ AS
  SELECT 'WIKIPEDIA' source, idpage id, page, section category, secText stext, lastUpdate, 'section' typeS
  FROM """ + tableFinal + """  UNION
  SELECT DISTINCT source, id, url, categories, concat(question, '|', answer), sourceDate, 'QA' typeS
  FROM """ + tableQA +  """;""")
            
db.saveDB(con)
db.closeDB(con)

# %%
### 9.4 Indexing

#### Start the service:

brew services start elasticsearch

# %%
from haystack import Finder
from haystack.preprocessor.cleaning import clean_wiki_text
from haystack.preprocessor.utils import convert_files_to_dicts, fetch_archive_from_http
from haystack.reader.farm import FARMReader
from haystack.reader.transformers import TransformersReader
from haystack.utils import print_answers

# %% [markdown]
# * Document Store
#
# FAISS is a library for efficient similarity search on a cluster of dense vectors. The FAISSDocumentStore uses a SQL(SQLite in-memory be default) database under-the-hood to store the document text and other meta data. The vector embeddings of the text are indexed on a FAISS Index that later is queried for searching answers.

# %%
from haystack.document_store.faiss import FAISSDocumentStore

document_store = FAISSDocumentStore(sql_url= "sqlite:///repoQA.db", faiss_index_factory_str="Flat", return_embedding=True) # The default flavour of FAISSDocumentStore is "Flat" but can also be set to "HNSW" for faster search at the expense of some accuracy. Just set the faiss_index_factor_str argument in the constructor.

# %%
* Cleaning documents

Here to convert and index Wikipedia articles to our DocumentStore.

Haystack provides a customizable pipeline for: converting files into texts, cleaning texts, splitting texts, writing them to a Document Store

# %%
# Let's first get some files that we want to use

#document_store =  ElasticsearchDocumentStore()
text_path = "../QA/corporaCOVID"

# Convert files to dicts

dicts = convert_files_to_dicts(dir_path= text_path, clean_func=clean_wiki_text, split_paragraphs=True)

print(dicts[0].keys()) # dict_keys(['text', 'meta'])
dicts[0]['meta'] # "name"

# %% [markdown]
# * Document Store
#
# Haystack finds answers to queries within the documents stored in a DocumentStore. The current implementations of DocumentStore include ElasticsearchDocumentStore, FAISSDocumentStore, SQLDocumentStore, and InMemoryDocumentStore.
#
# Here: We recommended Elasticsearch as it comes preloaded with features like full-text queries, BM25 retrieval, and vector storage for text embeddings.
#
# Alternatives: If you are unable to setup an Elasticsearch instance, then follow the Tutorial 3 for using SQL/InMemory document stores.
#
# Hint: This tutorial creates a new document store instance with Wikipedia articles on Game of Thrones. However, you can configure Haystack to work with your existing document stores.

# %%
# Now, let's write the dicts containing documents to our DB.
document_store.write_documents(dicts)

# %% [markdown]
# * Retriever
#
# Here: We use a DensePassageRetriever
# Alternatives:
#
# * The ElasticsearchRetriever with custom queries (e.g. boosting) and filters
# * Use EmbeddingRetriever to find candidate documents based on the similarity of embeddings (e.g. created via Sentence-BERT)
# * Use TfidfRetriever in combination with a SQL or InMemory Document store for simple prototyping and debugging
#
#
# Retrievers help narrowing down the scope for the Reader to smaller units of text where a given question could be answered. They use some simple but fast algorithm.
#
# Here: We use Elasticsearch's default BM25 algorithm
#
# * Use DensePassageRetriever to use different embedding models for passage and query (see Tutorial 6)
#
# Note, that DensePassageRetriever DPR works best when you index short passages < 512 tokens as only those tokens will be used for the embedding.
#
# * Here, for nq_dev_subset_v2.json we have avg. num of tokens = 5220(!).
# * DPR still outperforms Elastic's BM25 by a small margin here.
# * from haystack.retriever.dense import DensePassageRetriever

# %%
from haystack.retriever.dense import DensePassageRetriever

# retriever = ElasticsearchRetriever(document_store=document_store)
# Alternative: An in-memory TfidfRetriever based on Pandas dataframes for building quick-prototypes with SQLite document store.

# from haystack.retriever.sparse import TfidfRetriever
# retriever = TfidfRetriever(document_store=document_store)

max_len_query= 64 # 84
max_len_passage = 256

retriever = DensePassageRetriever(document_store=document_store,
                                  query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
                                  passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
                                  max_seq_len_query=max_len_query,
                                  max_seq_len_passage=max_len_passage,
                                  batch_size=16,
                                  use_gpu=True,
                                  embed_title=True,
                                  use_fast_tokenizers=True)
# Important: 
# Now that after we have the DPR initialized, we need to call update_embeddings() to iterate over all
# previously indexed documents and update their embedding representation. 
# While this can be a time consuming operation (depending on corpus size), it only needs to be done once. 
# At query time, we only need to embed the query and compare it the existing doc embeddings which is very fast.

document_store.update_embeddings(retriever)

# %%
# Save to disc:

document_store.save("../QA/data/DocStore")

# %% [markdown]
# # Testing with vectors of quora similar but not run

# %%
from haystack.document_store.faiss import FAISSDocumentStore

document_storeS = FAISSDocumentStore(sql_url= "sqlite:///repoQASim.db", faiss_index_factory_str="Flat", return_embedding=True) # The default flavour of FAISSDocumentStore is "Flat" but can also be set to "HNSW" for faster search at the expense of some accuracy. Just set the faiss_index_factor_str argument in the constructor. 

# Let's first get some files that we want to use

#document_store =  ElasticsearchDocumentStore()
text_path = "../QA/corporaCOVID"

# Convert files to dicts

dicts = convert_files_to_dicts(dir_path= text_path, clean_func=clean_wiki_text, split_paragraphs=True)

print(dicts[0].keys()) # dict_keys(['text', 'meta'])
dicts[0]['meta'] # "name"

# Now, let's write the dicts containing documents to our DB.
document_storeS.write_documents(dicts)

# %%
from sentence_transformers import SentenceTransformer, util
from transformers import AutoModelWithLMHead, AutoTokenizer, AutoModel
from transformers import DistilBertTokenizerFast
import os
import csv
import pickle
import time
import torch

model_name = "distilbert-base-nli-stsb-quora-ranking" # 'distilbert-multilingual-nli-stsb-quora-ranking'
#model = SentenceTransformer(model_name)



#tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased") #"mrm8488/t5-base-finetuned-squadv2")
#model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-squadv2")

max_corpus_size = 100000
embedding_cache_path = 'covid-embeddings-{}-size-{}.pkl'.format(model_name.replace('/', '_'), max_corpus_size)

embedding_cache_path

#model = AutoModel.from_pretrained(embedding_cache_path)
print("Load pre-computed embeddings from disc")
with open(embedding_cache_path, "rb") as fIn:
    cache_data = pickle.load(fIn)
    corpus_sentences = cache_data['sentences'][0:max_corpus_size]
    corpus_embeddings = cache_data['embeddings'][0:max_corpus_size]
###############################
print("Corpus loaded with {} sentences / embeddings".format(len(corpus_sentences)))

#model = SentenceTransformer(embedding_cache_path)

#model.load_state_dict(torch.load(embedding_cache_path))

#model.build_vocab(corpus_sentences, tokenize=True)

model = AutoModel.from_pretrained("../../PLNmodels/distilbert-base-nli-stsb-quora-ranking")

# %%
max_len_query= 64 # 84
max_len_passage = 256

retrieverQ = DensePassageRetriever(document_store=document_storeS,
                                  query_embedding_model= "../../PLNmodels/distilbert-base-nli-stsb-quora-ranking",
                                  passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
                                  max_seq_len_query=max_len_query,
                                  max_seq_len_passage=max_len_passage,
                                  batch_size=16,
                                  use_gpu=True,
                                  embed_title=True,
                                  use_fast_tokenizers=True)
# Important: 
# Now that after we have the DPR initialized, we need to call update_embeddings() to iterate over all
# previously indexed documents and update their embedding representation. 
# While this can be a time consuming operation (depending on corpus size), it only needs to be done once. 
# At query time, we only need to embed the query and compare it the existing doc embeddings which is very fast.

# %%
document_storeS.update_embeddings(retriever)

# %%
# Save to disc:

document_storeS.save("../QA/data/DocStoreSim")
